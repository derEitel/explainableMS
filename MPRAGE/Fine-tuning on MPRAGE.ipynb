# %% [markdown]
# For fine-tuning we have 3 datasets: train, validation and holdout

# %%
import numpy as np
import pandas as pd
import nibabel as nib
import nilearn

from scipy import interp
from sklearn.utils import shuffle
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, auc
from sklearn.model_selection import KFold

import matplotlib.pyplot as plt
import os
import time
import h5py

# keras
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.models import load_model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils import Sequence
import keras.backend as K

from config import *
from utils import specificity, sensitivity, balanced_accuracy, IntensityRescale, sagittal_flip, translate
# Out:
# Using TensorFlow backend.

# %%
# Start timing
start_time = time.time()

# %%
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session

config = tf.ConfigProto()
config.gpu_options.visible_device_list = "5"
set_session(tf.Session(config=config))

# %%
zero_one_normalize = True
dtype = np.float32
result_dir = "/analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/MPRAGE"

# %%
# !mkdir -p $result_dir

# %%
# load hdf5 files and extract columns
train_h5 = h5py.File('/analysis/share/Ritter/MS/CIS/train_dataset_MPRAGE.h5', 'r')
holdout_h5 = h5py.File('/analysis/share/Ritter/MS/CIS/holdout_dataset_MPRAGE.h5', 'r')

X_train, y_train = train_h5['X'], train_h5['y']
X_holdout, y_holdout = holdout_h5['X'], holdout_h5['y']

# %%
# convert data to numpy arrays
X_train = np.array(X_train, dtype=dtype)
y_train = np.array(y_train)

X_holdout = np.array(X_holdout, dtype=dtype)
y_holdout = np.array(y_holdout)

# %%
print("Total datset length: {}".format(len(y_train)))
print("Number of healthy controls: {}".format(len(np.array(y_train)[np.array(y_train)==0.])))
print("Number of MS patients: {}".format(len(np.array(y_train)[np.array(y_train)==1.])))
# Out:
# Total datset length: 124
# Number of healthy controls: 61
# Number of MS patients: 63

# %%
class CISDataset(Sequence):
    def __init__(self, X, y, transform=None, batch_size=4, z_factor=None, shuffle=True, mask=None):
        self.X = X
        self.y = y
        self.transform = transform
        self.batch_size = batch_size
        self.z_factor = z_factor
        self.shuffle = shuffle
        self.mask = mask
        
    def __len__(self):
        return int(np.ceil(len(self.y)/self.batch_size))
    
    def __getitem__(self, idx):
        # add BET
        image = np.expand_dims(self.X[idx * self.batch_size:(idx + 1) * self.batch_size],5)
        #label = np.array((batch_idx['label'] == "MS")* 1, dtype=np.int8) 
        label = np.array(self.y[idx * self.batch_size:(idx + 1) * self.batch_size], dtype=np.int8)
        
        if self.mask is not None:
            for i in range(image.shape[0]):
                image[i] *= self.mask
        
        for transformation in self.transform:
            image = transformation(image)
        
        return image, label
    
    def on_epoch_end(self):
        if self.shuffle:
            self.X, self.y = shuffle(self.X, self.y)

# %%
mask = None

# %%
intensity = IntensityRescale(masked=False)

# %%
if zero_one_normalize:
    cis_data = CISDataset(X_train, y_train, transform=[intensity], batch_size=4)
else:
    cis_data = CISDataset(X_train, y_train, batch_size=4)

# %%
plt.figure()
plt.title("Normalized between zero and 1")
plt.hist(cis_data[4][0][0].flatten())
plt.show()
# Out:
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()

# %%
plt.figure()
plt.title("Scan image")
plt.imshow(np.squeeze(cis_data[4][0][0])[:,:,42], cmap='gray')
plt.show()
# Out:
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()

# %% [markdown]
# # Model

# %%
def init_model(path, finetune=True, up_to=7):
    model = load_model(path)
    model.load_weights(path)
    if finetune:
        for layer in model.layers[:up_to]:
            layer.trainable = False
    return model

# %%
# load model weights
model_path = "/analysis/share/Ritter/models/fabi/ADNI/pretraining_paper/model_trial_7.h5"
model = init_model(model_path, finetune=False, up_to=None)
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Conv_1 (Conv3D)              (None, 94, 112, 94, 64)   1792
# _________________________________________________________________
# Pool_1 (MaxPooling3D)        (None, 31, 37, 31, 64)    0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 31, 37, 31, 64)    0
# _________________________________________________________________
# Conv_2 (Conv3D)              (None, 29, 35, 29, 64)    110656
# _________________________________________________________________
# Pool_2 (MaxPooling3D)        (None, 9, 11, 9, 64)      0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 9, 11, 9, 64)      0
# _________________________________________________________________
# Conv_3 (Conv3D)              (None, 7, 9, 7, 64)       110656
# _________________________________________________________________
# Conv_4 (Conv3D)              (None, 5, 7, 5, 64)       110656
# _________________________________________________________________
# Pool_4 (MaxPooling3D)        (None, 1, 2, 1, 64)       0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 1, 2, 1, 64)       0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 333,889
# Trainable params: 333,889
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Visualization

# %%
def visualize_weights(model):
    # Visualize weights
    W = model.layers[0].get_weights()[0]
    W = np.squeeze(W)[:,:,2]
    print("W shape : ", W.shape)

    print("Weights mean {}".format(W.mean()))
    plt.figure(figsize=(20, 5))
    plt.title('conv1 weights')
    plt.imshow(make_mosaic(W, 2, 2), cmap="gray")
    plt.show()

# %%
import numpy.ma as ma
def make_mosaic(imgs, nrows, ncols, border=1):
    """
    Given a set of images with all the same shape, makes a
    mosaic with nrows and ncols
    """
    nimgs = imgs.shape[0]
    imshape = imgs.shape[1:]
    
    mosaic = ma.masked_all((nrows * imshape[0] + (nrows - 1) * border,
                            ncols * imshape[1] + (ncols - 1) * border),
                            dtype=np.float32)
    
    paddedh = imshape[0] + border
    paddedw = imshape[1] + border
    for i in range(nimgs):
        row = int(np.floor(i / ncols))
        col = i % ncols
        
        mosaic[row * paddedh:row * paddedh + imshape[0],
               col * paddedw:col * paddedw + imshape[1]] = imgs[i]
    return mosaic

# %%
def reset_weights(model):
    session = K.get_session()
    for layer in model.layers: 
        if hasattr(layer, 'kernel_initializer'):
            layer.kernel.initializer.run(session=session)

# %%
# Visualize weights
print("Pre-trained model layer 1 weights:")
visualize_weights(model)
model_untrained = load_model(model_path)
reset_weights(model_untrained)
print("Random model layer 1 weights:")
visualize_weights(model_untrained)
# Out:
# Pre-trained model layer 1 weights:
# W shape :  (3, 3, 64)
# Weights mean -0.0022606917191296816
# Random model layer 1 weights:
# W shape :  (3, 3, 64)
# Weights mean -0.0011678553419187665

# %% [markdown]
# ## Training

# %%
X_train.shape
# Out:
# (124, 96, 114, 96)

# %%
from sklearn.model_selection import train_test_split

# %%
# split training set
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.15, random_state=77)

# %%
# training args
lr = 0.001
lr_decay = 0.003
transforms = [intensity, sagittal_flip, translate]

num_trials = 10
store_models = True

accuracies = []
balanced_accuracies = []
sensitivities = []
specificities = []
max_acc = []

for i in range(num_trials):
    print("Trial %i" %i)
    
    # init model
    model = init_model(model_path, finetune=False, up_to=None)    
    opti = Adam(lr=lr, decay=lr_decay)
    model.compile(optimizer=opti, loss='binary_crossentropy', metrics=['accuracy'])
    
    # callbacks
    earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=15, verbose=1, mode='auto')
    if store_models:
        result_path = os.path.join(result_dir, "weights-augm-trial%i-improvement-BEST.hdf5" %i)
        model_checkpoint = ModelCheckpoint(result_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max', save_weights_only=True)
        callbacks = [earlystop, model_checkpoint]
    else:
        callbacks = [earlystop]
        
    train_loader = CISDataset(X_train, y_train, transform=transforms, batch_size=b, shuffle=True)
    val_loader = CISDataset(X_val, y_val, transform=[intensity], batch_size=4, shuffle=False)
    
    # Start training
    history = model.fit_generator(train_loader,
                        epochs=num_epochs,
                        validation_data=val_loader,
                        callbacks=callbacks)
    # Plot training curves
    plt.figure(figsize=(11, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history["loss"])
    plt.plot(history.history["val_loss"])
    plt.legend(["Train", "Val"])
    plt.title("Loss")
    plt.subplot(1, 2, 2)
    plt.plot(history.history["acc"])
    plt.plot(history.history["val_acc"])
    plt.legend(["Train", "Val"])
    plt.title("Accuracy")
    plt.show()
    # Evaluation
    y_pred = model.predict_generator(val_loader)
    #y_true = [item for sublist in [val_loader[batch_idx][1] for batch_idx in range(len(val_loader))] for item in sublist]
    bal_acc = balanced_accuracy(y_val, y_pred>0.5)
    sens = sensitivity(y_val, y_pred>0.5)
    spec = specificity(y_val, y_pred>0.5)
    # Store results
    accuracies.append(history.history["val_acc"][-1])
    balanced_accuracies.append(bal_acc)
    max_acc.append(np.max(history.history["val_acc"]))
    sensitivities.append(sens)
    specificities.append(spec)

training_time = time.time() - start_time
print("Training Time: {}h:{}m:{}s".format(
            training_time//3600, (training_time//60)%60, training_time%60))
# Print results
print("Validation final accuracies: \n {}".format(accuracies))
print("Validation final accuracies mean: {}".format(np.mean(accuracies)))
print("Validation best accuracies: \n {}".format(max_acc))
print("Validation best accuracies mean: {}".format(np.mean(max_acc)))
print("Validation balanced accuracies: \n {}".format(balanced_accuracies))
print("Validation balanced accuracies mean: {}".format(np.mean(balanced_accuracies)))
print("Validation final sensitivities: \n {}".format(sensitivities))
print("Validation final sensitivities' mean: {}".format(np.mean(sensitivities)))
print("Validation final specificities: \n {}".format(specificities))
print("Validation final specificities' mean: {}".format(np.mean(specificities)))
# Out:
# Trial 0
# Epoch 1/200
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()
# 27/27 [==============================] - 9s 317ms/step - loss: 1.1010 - acc: 0.5190 - val_loss: 1.3256 - val_acc: 0.3158
#
# Epoch 00001: val_acc improved from -inf to 0.31579, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/MPRAGE/weights-augm-trial0-improvement-BEST.hdf5
# Epoch 2/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.9522 - acc: 0.5922 - val_loss: 1.2344 - val_acc: 0.3158
#
# Epoch 00002: val_acc did not improve from 0.31579
# Epoch 3/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.9897 - acc: 0.6014 - val_loss: 0.8184 - val_acc: 0.6842
#
# Epoch 00003: val_acc improved from 0.31579 to 0.68421, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/MPRAGE/weights-augm-trial0-improvement-BEST.hdf5
# Epoch 4/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.9945 - acc: 0.4810 - val_loss: 0.9008 - val_acc: 0.3684
#
# Epoch 00004: val_acc did not improve from 0.68421
# Epoch 5/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.9063 - acc: 0.5366 - val_loss: 0.8169 - val_acc: 0.6842
#
# Epoch 00005: val_acc did not improve from 0.68421
# Epoch 6/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.8955 - acc: 0.4820 - val_loss: 0.8614 - val_acc: 0.3684
#
# Epoch 00006: val_acc did not improve from 0.68421
# Epoch 7/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.8950 - acc: 0.5190 - val_loss: 0.8018 - val_acc: 0.6842
#
# Epoch 00007: val_acc did not improve from 0.68421
# Epoch 8/200
# 27/27 [==============================] - 4s 154ms/step - loss: 0.9056 - acc: 0.5273 - val_loss: 0.9511 - val_acc: 0.3158
#
# Epoch 00008: val_acc did not improve from 0.68421
# Epoch 9/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.7917 - acc: 0.6571 - val_loss: 0.8268 - val_acc: 0.3158
#
# Epoch 00009: val_acc did not improve from 0.68421
# Epoch 10/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.8414 - acc: 0.5088 - val_loss: 0.8981 - val_acc: 0.3158
#
# Epoch 00010: val_acc did not improve from 0.68421
# Epoch 11/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.7938 - acc: 0.5922 - val_loss: 0.8580 - val_acc: 0.3158
#
# Epoch 00011: val_acc did not improve from 0.68421
# Epoch 12/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.8013 - acc: 0.5376 - val_loss: 0.7830 - val_acc: 0.5263
#
# Epoch 00012: val_acc did not improve from 0.68421
# Epoch 13/200
# 27/27 [==============================] - 5s 169ms/step - loss: 0.7944 - acc: 0.5098 - val_loss: 0.8217 - val_acc: 0.3158
#
# Epoch 00013: val_acc did not improve from 0.68421
# Epoch 14/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.7895 - acc: 0.5366 - val_loss: 0.8021 - val_acc: 0.4737
#
# Epoch 00014: val_acc did not improve from 0.68421
# Epoch 15/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.7773 - acc: 0.5551 - val_loss: 0.9986 - val_acc: 0.3158
#
# Epoch 00015: val_acc did not improve from 0.68421
# Epoch 16/200
# 27/27 [==============================] - 5s 176ms/step - loss: 0.7387 - acc: 0.5458 - val_loss: 0.8444 - val_acc: 0.4737
#
# Epoch 00016: val_acc did not improve from 0.68421
# Epoch 17/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.7350 - acc: 0.6200 - val_loss: 0.8769 - val_acc: 0.4211
#
# Epoch 00017: val_acc did not improve from 0.68421
# Epoch 18/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.7134 - acc: 0.6571 - val_loss: 0.8750 - val_acc: 0.4737
#
# Epoch 00018: val_acc did not improve from 0.68421
# Epoch 19/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.7274 - acc: 0.6385 - val_loss: 0.8405 - val_acc: 0.5263
#
# Epoch 00019: val_acc did not improve from 0.68421
# Epoch 20/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.7058 - acc: 0.6107 - val_loss: 1.0476 - val_acc: 0.3158
#
# Epoch 00020: val_acc did not improve from 0.68421
# Epoch 21/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.7112 - acc: 0.6117 - val_loss: 0.8632 - val_acc: 0.4211
#
# Epoch 00021: val_acc did not improve from 0.68421
# Epoch 22/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.6890 - acc: 0.6200 - val_loss: 0.9623 - val_acc: 0.4211
#
# Epoch 00022: val_acc did not improve from 0.68421
# Epoch 23/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.6721 - acc: 0.6941 - val_loss: 0.9137 - val_acc: 0.4211
#
# Epoch 00023: val_acc did not improve from 0.68421
# Epoch 24/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.6678 - acc: 0.6849 - val_loss: 1.1257 - val_acc: 0.3684
#
# Epoch 00024: val_acc did not improve from 0.68421
# Epoch 25/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.6916 - acc: 0.6571 - val_loss: 0.9501 - val_acc: 0.4211
#
# Epoch 00025: val_acc did not improve from 0.68421
# Epoch 26/200
# 27/27 [==============================] - 5s 173ms/step - loss: 0.6708 - acc: 0.7034 - val_loss: 1.0752 - val_acc: 0.4211
#
# Epoch 00026: val_acc did not improve from 0.68421
# Epoch 27/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.6763 - acc: 0.6766 - val_loss: 0.8284 - val_acc: 0.4737
#
# Epoch 00027: val_acc did not improve from 0.68421
# Epoch 00027: early stopping
# Trial 1
# Epoch 1/200
# 27/27 [==============================] - 6s 207ms/step - loss: 1.0187 - acc: 0.5366 - val_loss: 0.8476 - val_acc: 0.6842
#
# Epoch 00001: val_acc improved from -inf to 0.68421, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/MPRAGE/weights-augm-trial1-improvement-BEST.hdf5
# Epoch 2/200
# 27/27 [==============================] - 4s 155ms/step - loss: 1.0401 - acc: 0.3975 - val_loss: 0.8980 - val_acc: 0.4211
#
# Epoch 00002: val_acc did not improve from 0.68421
# Epoch 3/200
# 27/27 [==============================] - 4s 153ms/step - loss: 0.9881 - acc: 0.4995 - val_loss: 0.8217 - val_acc: 0.6842
#
# Epoch 00003: val_acc did not improve from 0.68421
# Epoch 4/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.9551 - acc: 0.5098 - val_loss: 0.9164 - val_acc: 0.3158
#
# Epoch 00004: val_acc did not improve from 0.68421
# Epoch 5/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.9283 - acc: 0.4068 - val_loss: 0.7951 - val_acc: 0.6842
#
# Epoch 00005: val_acc did not improve from 0.68421
# Epoch 6/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.8109 - acc: 0.5922 - val_loss: 0.8915 - val_acc: 0.3158
#
# Epoch 00006: val_acc did not improve from 0.68421
# Epoch 7/200
# 27/27 [==============================] - 4s 154ms/step - loss: 0.9119 - acc: 0.4078 - val_loss: 0.9348 - val_acc: 0.3158
#
# Epoch 00007: val_acc did not improve from 0.68421
# Epoch 8/200
# 27/27 [==============================] - 4s 167ms/step - loss: 0.8353 - acc: 0.6014 - val_loss: 0.9139 - val_acc: 0.3158
#
# Epoch 00008: val_acc did not improve from 0.68421
# Epoch 9/200
# 27/27 [==============================] - 4s 155ms/step - loss: 0.9242 - acc: 0.4634 - val_loss: 0.8904 - val_acc: 0.3158
#
# Epoch 00009: val_acc did not improve from 0.68421
# Epoch 10/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.8309 - acc: 0.5469 - val_loss: 0.9030 - val_acc: 0.3158
#
# Epoch 00010: val_acc did not improve from 0.68421
# Epoch 11/200
# 27/27 [==============================] - 4s 153ms/step - loss: 0.8861 - acc: 0.4542 - val_loss: 0.7512 - val_acc: 0.6842
#
# Epoch 00011: val_acc did not improve from 0.68421
# Epoch 12/200
# 27/27 [==============================] - 4s 167ms/step - loss: 0.8092 - acc: 0.5736 - val_loss: 0.8489 - val_acc: 0.3158
#
# Epoch 00012: val_acc did not improve from 0.68421
# Epoch 13/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.7751 - acc: 0.5098 - val_loss: 0.7816 - val_acc: 0.3158
#
# Epoch 00013: val_acc did not improve from 0.68421
# Epoch 14/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.8222 - acc: 0.4634 - val_loss: 0.7828 - val_acc: 0.3158
#
# Epoch 00014: val_acc did not improve from 0.68421
# Epoch 15/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.7895 - acc: 0.5190 - val_loss: 0.8496 - val_acc: 0.3158
#
# Epoch 00015: val_acc did not improve from 0.68421
# Epoch 16/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.7964 - acc: 0.4449 - val_loss: 0.7508 - val_acc: 0.5263
#
# Epoch 00016: val_acc did not improve from 0.68421
# Epoch 17/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.7832 - acc: 0.5283 - val_loss: 0.7743 - val_acc: 0.3158
#
# Epoch 00017: val_acc did not improve from 0.68421
# Epoch 18/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.7547 - acc: 0.4912 - val_loss: 0.7757 - val_acc: 0.3158
#
# Epoch 00018: val_acc did not improve from 0.68421
# Epoch 19/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.7427 - acc: 0.5551 - val_loss: 0.7479 - val_acc: 0.5263
#
# Epoch 00019: val_acc did not improve from 0.68421
# Epoch 20/200
# 27/27 [==============================] - 4s 152ms/step - loss: 0.7573 - acc: 0.6014 - val_loss: 0.7235 - val_acc: 0.6316
#
# Epoch 00020: val_acc did not improve from 0.68421
# Epoch 21/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.7423 - acc: 0.5458 - val_loss: 0.9049 - val_acc: 0.3158
#
# Epoch 00021: val_acc did not improve from 0.68421
# Epoch 22/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.7458 - acc: 0.4634 - val_loss: 0.7673 - val_acc: 0.4211
#
# Epoch 00022: val_acc did not improve from 0.68421
# Epoch 23/200
# 27/27 [==============================] - 5s 169ms/step - loss: 0.7207 - acc: 0.5644 - val_loss: 0.8270 - val_acc: 0.3158
#
# Epoch 00023: val_acc did not improve from 0.68421
# Epoch 24/200
# 27/27 [==============================] - 5s 175ms/step - loss: 0.7281 - acc: 0.5180 - val_loss: 0.8173 - val_acc: 0.3684
#
# Epoch 00024: val_acc did not improve from 0.68421
# Epoch 25/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.7070 - acc: 0.5932 - val_loss: 0.8095 - val_acc: 0.3158
#
# Epoch 00025: val_acc did not improve from 0.68421
# Epoch 26/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.6927 - acc: 0.6200 - val_loss: 0.7671 - val_acc: 0.4737
#
# Epoch 00026: val_acc did not improve from 0.68421
# Epoch 27/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.7002 - acc: 0.5551 - val_loss: 0.7523 - val_acc: 0.5263
#
# Epoch 00027: val_acc did not improve from 0.68421
# Epoch 28/200
# 27/27 [==============================] - 5s 170ms/step - loss: 0.7048 - acc: 0.5922 - val_loss: 0.7930 - val_acc: 0.4737
#
# Epoch 00028: val_acc did not improve from 0.68421
# Epoch 29/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.6727 - acc: 0.6478 - val_loss: 0.8618 - val_acc: 0.4211
#
# Epoch 00029: val_acc did not improve from 0.68421
# Epoch 30/200
# 27/27 [==============================] - 5s 181ms/step - loss: 0.6826 - acc: 0.7405 - val_loss: 0.8879 - val_acc: 0.4211
#
# Epoch 00030: val_acc did not improve from 0.68421
# Epoch 31/200
# 27/27 [==============================] - 4s 154ms/step - loss: 0.6690 - acc: 0.6303 - val_loss: 0.7837 - val_acc: 0.4737
#
# Epoch 00031: val_acc did not improve from 0.68421
# Epoch 32/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.6698 - acc: 0.6663 - val_loss: 0.8734 - val_acc: 0.5263
#
# Epoch 00032: val_acc did not improve from 0.68421
# Epoch 33/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.6573 - acc: 0.6385 - val_loss: 0.9785 - val_acc: 0.3684
#
# Epoch 00033: val_acc did not improve from 0.68421
# Epoch 34/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.6176 - acc: 0.6673 - val_loss: 0.8351 - val_acc: 0.4737
#
# Epoch 00034: val_acc did not improve from 0.68421
# Epoch 35/200
# 27/27 [==============================] - 5s 179ms/step - loss: 0.6447 - acc: 0.7219 - val_loss: 0.9176 - val_acc: 0.4211
#
# Epoch 00035: val_acc did not improve from 0.68421
# Epoch 00035: early stopping
# Trial 2
# Epoch 1/200
# 27/27 [==============================] - 6s 215ms/step - loss: 1.0549 - acc: 0.4902 - val_loss: 0.8604 - val_acc: 0.6842
#
# Epoch 00001: val_acc improved from -inf to 0.68421, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/MPRAGE/weights-augm-trial2-improvement-BEST.hdf5
# Epoch 2/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.9754 - acc: 0.5088 - val_loss: 0.8882 - val_acc: 0.3158
#
# Epoch 00002: val_acc did not improve from 0.68421
# Epoch 3/200
# 27/27 [==============================] - 5s 171ms/step - loss: 0.9837 - acc: 0.4995 - val_loss: 1.0476 - val_acc: 0.3158
#
# Epoch 00003: val_acc did not improve from 0.68421
# Epoch 4/200
# 27/27 [==============================] - 5s 173ms/step - loss: 0.9398 - acc: 0.5469 - val_loss: 0.9231 - val_acc: 0.3158
#
# Epoch 00004: val_acc did not improve from 0.68421
# Epoch 5/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.9676 - acc: 0.5180 - val_loss: 0.9033 - val_acc: 0.3158
#
# Epoch 00005: val_acc did not improve from 0.68421
# Epoch 6/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.9141 - acc: 0.4912 - val_loss: 0.8441 - val_acc: 0.3158
#
# Epoch 00006: val_acc did not improve from 0.68421
# Epoch 7/200
# 27/27 [==============================] - 4s 155ms/step - loss: 0.8711 - acc: 0.5005 - val_loss: 0.9962 - val_acc: 0.3158
#
# Epoch 00007: val_acc did not improve from 0.68421
# Epoch 8/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.8945 - acc: 0.4810 - val_loss: 0.8104 - val_acc: 0.3158
#
# Epoch 00008: val_acc did not improve from 0.68421
# Epoch 9/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.7762 - acc: 0.5644 - val_loss: 0.8571 - val_acc: 0.3158
#
# Epoch 00009: val_acc did not improve from 0.68421
# Epoch 10/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.8510 - acc: 0.5088 - val_loss: 0.8327 - val_acc: 0.3158
#
# Epoch 00010: val_acc did not improve from 0.68421
# Epoch 11/200
# 27/27 [==============================] - 5s 169ms/step - loss: 0.8487 - acc: 0.4542 - val_loss: 0.8140 - val_acc: 0.3158
#
# Epoch 00011: val_acc did not improve from 0.68421
# Epoch 12/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.7727 - acc: 0.6200 - val_loss: 0.8201 - val_acc: 0.3158
#
# Epoch 00012: val_acc did not improve from 0.68421
# Epoch 13/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.8273 - acc: 0.4356 - val_loss: 0.8015 - val_acc: 0.3158
#
# Epoch 00013: val_acc did not improve from 0.68421
# Epoch 14/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.7646 - acc: 0.5922 - val_loss: 0.7627 - val_acc: 0.4211
#
# Epoch 00014: val_acc did not improve from 0.68421
# Epoch 15/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.7886 - acc: 0.5098 - val_loss: 0.7701 - val_acc: 0.3684
#
# Epoch 00015: val_acc did not improve from 0.68421
# Epoch 16/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.7628 - acc: 0.5005 - val_loss: 0.7602 - val_acc: 0.5263
#
# Epoch 00016: val_acc did not improve from 0.68421
# Epoch 17/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.7365 - acc: 0.5839 - val_loss: 0.7825 - val_acc: 0.4211
#
# Epoch 00017: val_acc did not improve from 0.68421
# Epoch 18/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.7400 - acc: 0.5551 - val_loss: 0.8099 - val_acc: 0.3158
#
# Epoch 00018: val_acc did not improve from 0.68421
# Epoch 19/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.7403 - acc: 0.5098 - val_loss: 0.7886 - val_acc: 0.3684
#
# Epoch 00019: val_acc did not improve from 0.68421
# Epoch 20/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.7185 - acc: 0.5839 - val_loss: 0.7611 - val_acc: 0.4737
#
# Epoch 00020: val_acc did not improve from 0.68421
# Epoch 21/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.7158 - acc: 0.5736 - val_loss: 0.7696 - val_acc: 0.5789
#
# Epoch 00021: val_acc did not improve from 0.68421
# Epoch 22/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.7129 - acc: 0.5654 - val_loss: 0.7004 - val_acc: 0.5263
#
# Epoch 00022: val_acc did not improve from 0.68421
# Epoch 23/200
# 27/27 [==============================] - 5s 172ms/step - loss: 0.6995 - acc: 0.6385 - val_loss: 0.7607 - val_acc: 0.5263
#
# Epoch 00023: val_acc did not improve from 0.68421
# Epoch 24/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.6616 - acc: 0.6766 - val_loss: 0.7662 - val_acc: 0.5789
#
# Epoch 00024: val_acc did not improve from 0.68421
# Epoch 25/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.6855 - acc: 0.6478 - val_loss: 0.7907 - val_acc: 0.4211
#
# Epoch 00025: val_acc did not improve from 0.68421
# Epoch 26/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.6517 - acc: 0.6941 - val_loss: 0.8566 - val_acc: 0.4211
#
# Epoch 00026: val_acc did not improve from 0.68421
# Epoch 27/200
# 27/27 [==============================] - 4s 167ms/step - loss: 0.6715 - acc: 0.6756 - val_loss: 0.8282 - val_acc: 0.4211
#
# Epoch 00027: val_acc did not improve from 0.68421
# Epoch 28/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.6641 - acc: 0.6941 - val_loss: 0.8553 - val_acc: 0.3684
#
# Epoch 00028: val_acc did not improve from 0.68421
# Epoch 29/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.6155 - acc: 0.6663 - val_loss: 0.8552 - val_acc: 0.3158
#
# Epoch 00029: val_acc did not improve from 0.68421
# Epoch 30/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.6694 - acc: 0.6756 - val_loss: 0.9040 - val_acc: 0.3684
#
# Epoch 00030: val_acc did not improve from 0.68421
# Epoch 31/200
# 27/27 [==============================] - 5s 171ms/step - loss: 0.6339 - acc: 0.7322 - val_loss: 0.8637 - val_acc: 0.3158
#
# Epoch 00031: val_acc did not improve from 0.68421
# Epoch 32/200
# 27/27 [==============================] - 5s 171ms/step - loss: 0.6669 - acc: 0.6766 - val_loss: 0.9942 - val_acc: 0.3684
#
# Epoch 00032: val_acc did not improve from 0.68421
# Epoch 33/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.6505 - acc: 0.7034 - val_loss: 1.1116 - val_acc: 0.3684
#
# Epoch 00033: val_acc did not improve from 0.68421
# Epoch 34/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.6162 - acc: 0.7405 - val_loss: 1.0248 - val_acc: 0.3684
#
# Epoch 00034: val_acc did not improve from 0.68421
# Epoch 35/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.6116 - acc: 0.7312 - val_loss: 1.1597 - val_acc: 0.3684
#
# Epoch 00035: val_acc did not improve from 0.68421
# Epoch 36/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.5917 - acc: 0.7034 - val_loss: 1.0233 - val_acc: 0.4211
#
# Epoch 00036: val_acc did not improve from 0.68421
# Epoch 37/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.5888 - acc: 0.7312 - val_loss: 1.2250 - val_acc: 0.3684
#
# Epoch 00037: val_acc did not improve from 0.68421
# Epoch 00037: early stopping
# Trial 3
# Epoch 1/200
# 27/27 [==============================] - 6s 229ms/step - loss: 1.0694 - acc: 0.4171 - val_loss: 0.8961 - val_acc: 0.6316
#
# Epoch 00001: val_acc improved from -inf to 0.63158, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/MPRAGE/weights-augm-trial3-improvement-BEST.hdf5
# Epoch 2/200
# 27/27 [==============================] - 4s 158ms/step - loss: 1.1284 - acc: 0.5376 - val_loss: 1.0508 - val_acc: 0.3158
#
# Epoch 00002: val_acc did not improve from 0.63158
# Epoch 3/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.9785 - acc: 0.4542 - val_loss: 1.2212 - val_acc: 0.3158
#
# Epoch 00003: val_acc did not improve from 0.63158
# Epoch 4/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.9654 - acc: 0.5005 - val_loss: 0.9914 - val_acc: 0.3158
#
# Epoch 00004: val_acc did not improve from 0.63158
# Epoch 5/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.9705 - acc: 0.5283 - val_loss: 0.9704 - val_acc: 0.3158
#
# Epoch 00005: val_acc did not improve from 0.63158
# Epoch 6/200
# 27/27 [==============================] - 5s 172ms/step - loss: 0.9448 - acc: 0.5273 - val_loss: 0.8675 - val_acc: 0.3158
#
# Epoch 00006: val_acc did not improve from 0.63158
# Epoch 7/200
# 27/27 [==============================] - 5s 170ms/step - loss: 0.8730 - acc: 0.5551 - val_loss: 0.8281 - val_acc: 0.6842
#
# Epoch 00007: val_acc improved from 0.63158 to 0.68421, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/MPRAGE/weights-augm-trial3-improvement-BEST.hdf5
# Epoch 8/200
# 27/27 [==============================] - 5s 178ms/step - loss: 0.9106 - acc: 0.5551 - val_loss: 0.8996 - val_acc: 0.3158
#
# Epoch 00008: val_acc did not improve from 0.68421
# Epoch 9/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.8398 - acc: 0.5283 - val_loss: 0.8780 - val_acc: 0.3158
#
# Epoch 00009: val_acc did not improve from 0.68421
# Epoch 10/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.8639 - acc: 0.5088 - val_loss: 0.8264 - val_acc: 0.3158
#
# Epoch 00010: val_acc did not improve from 0.68421
# Epoch 11/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.8672 - acc: 0.4264 - val_loss: 0.7580 - val_acc: 0.6842
#
# Epoch 00011: val_acc did not improve from 0.68421
# Epoch 12/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.8281 - acc: 0.5376 - val_loss: 0.7956 - val_acc: 0.3684
#
# Epoch 00012: val_acc did not improve from 0.68421
# Epoch 13/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.7895 - acc: 0.5551 - val_loss: 0.7220 - val_acc: 0.6842
#
# Epoch 00013: val_acc improved from 0.68421 to 0.68421, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/MPRAGE/weights-augm-trial3-improvement-BEST.hdf5
# Epoch 14/200
# 27/27 [==============================] - 5s 171ms/step - loss: 0.8394 - acc: 0.5736 - val_loss: 0.7910 - val_acc: 0.4737
#
# Epoch 00014: val_acc did not improve from 0.68421
# Epoch 15/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.8283 - acc: 0.5654 - val_loss: 0.7968 - val_acc: 0.3158
#
# Epoch 00015: val_acc did not improve from 0.68421
# Epoch 16/200
# 27/27 [==============================] - 4s 155ms/step - loss: 0.7860 - acc: 0.4902 - val_loss: 0.8156 - val_acc: 0.3158
#
# Epoch 00016: val_acc did not improve from 0.68421
# Epoch 17/200
# 27/27 [==============================] - 5s 172ms/step - loss: 0.8238 - acc: 0.4542 - val_loss: 0.7895 - val_acc: 0.3158
#
# Epoch 00017: val_acc did not improve from 0.68421
# Epoch 18/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.8110 - acc: 0.4912 - val_loss: 0.7692 - val_acc: 0.3158
#
# Epoch 00018: val_acc did not improve from 0.68421
# Epoch 19/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.7864 - acc: 0.4727 - val_loss: 0.7813 - val_acc: 0.3158
#
# Epoch 00019: val_acc did not improve from 0.68421
# Epoch 20/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.7589 - acc: 0.5932 - val_loss: 0.7935 - val_acc: 0.3158
#
# Epoch 00020: val_acc did not improve from 0.68421
# Epoch 21/200
# 27/27 [==============================] - 4s 154ms/step - loss: 0.7566 - acc: 0.5561 - val_loss: 0.7722 - val_acc: 0.3158
#
# Epoch 00021: val_acc did not improve from 0.68421
# Epoch 22/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.7638 - acc: 0.5273 - val_loss: 0.7864 - val_acc: 0.3158
#
# Epoch 00022: val_acc did not improve from 0.68421
# Epoch 23/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.7335 - acc: 0.6025 - val_loss: 0.7598 - val_acc: 0.4211
#
# Epoch 00023: val_acc did not improve from 0.68421
# Epoch 24/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.7702 - acc: 0.5098 - val_loss: 0.8011 - val_acc: 0.3158
#
# Epoch 00024: val_acc did not improve from 0.68421
# Epoch 25/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.7259 - acc: 0.6014 - val_loss: 0.7559 - val_acc: 0.3684
#
# Epoch 00025: val_acc did not improve from 0.68421
# Epoch 26/200
# 27/27 [==============================] - 5s 169ms/step - loss: 0.7335 - acc: 0.5561 - val_loss: 0.7913 - val_acc: 0.3158
#
# Epoch 00026: val_acc did not improve from 0.68421
# Epoch 27/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.7233 - acc: 0.5654 - val_loss: 0.8029 - val_acc: 0.3158
#
# Epoch 00027: val_acc did not improve from 0.68421
# Epoch 28/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.7298 - acc: 0.5180 - val_loss: 0.8104 - val_acc: 0.3158
#
# Epoch 00028: val_acc did not improve from 0.68421
# Epoch 00028: early stopping
# Trial 4
# Epoch 1/200
# 27/27 [==============================] - 6s 231ms/step - loss: 1.1178 - acc: 0.4902 - val_loss: 0.9234 - val_acc: 0.3158
#
# Epoch 00001: val_acc improved from -inf to 0.31579, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/MPRAGE/weights-augm-trial4-improvement-BEST.hdf5
# Epoch 2/200
# 27/27 [==============================] - 4s 159ms/step - loss: 1.0330 - acc: 0.4449 - val_loss: 1.0142 - val_acc: 0.3158
#
# Epoch 00002: val_acc did not improve from 0.31579
# Epoch 3/200
# 27/27 [==============================] - 4s 153ms/step - loss: 0.9630 - acc: 0.4531 - val_loss: 0.7778 - val_acc: 0.6842
#
# Epoch 00003: val_acc improved from 0.31579 to 0.68421, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/MPRAGE/weights-augm-trial4-improvement-BEST.hdf5
# Epoch 4/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.9197 - acc: 0.5458 - val_loss: 0.9583 - val_acc: 0.3158
#
# Epoch 00004: val_acc did not improve from 0.68421
# Epoch 5/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.8906 - acc: 0.5088 - val_loss: 0.9170 - val_acc: 0.3158
#
# Epoch 00005: val_acc did not improve from 0.68421
# Epoch 6/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.8766 - acc: 0.4820 - val_loss: 0.8583 - val_acc: 0.3158
#
# Epoch 00006: val_acc did not improve from 0.68421
# Epoch 7/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.8546 - acc: 0.5190 - val_loss: 0.8202 - val_acc: 0.3158
#
# Epoch 00007: val_acc did not improve from 0.68421
# Epoch 8/200
# 27/27 [==============================] - 4s 155ms/step - loss: 0.8156 - acc: 0.5180 - val_loss: 0.7944 - val_acc: 0.3158
#
# Epoch 00008: val_acc did not improve from 0.68421
# Epoch 9/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.8194 - acc: 0.5376 - val_loss: 0.7615 - val_acc: 0.6842
#
# Epoch 00009: val_acc did not improve from 0.68421
# Epoch 10/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.7965 - acc: 0.5736 - val_loss: 0.7955 - val_acc: 0.3158
#
# Epoch 00010: val_acc did not improve from 0.68421
# Epoch 11/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.8137 - acc: 0.5747 - val_loss: 0.7888 - val_acc: 0.3158
#
# Epoch 00011: val_acc did not improve from 0.68421
# Epoch 12/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.7835 - acc: 0.5458 - val_loss: 0.8655 - val_acc: 0.3158
#
# Epoch 00012: val_acc did not improve from 0.68421
# Epoch 13/200
# 27/27 [==============================] - 4s 155ms/step - loss: 0.7574 - acc: 0.6293 - val_loss: 0.8761 - val_acc: 0.3158
#
# Epoch 00013: val_acc did not improve from 0.68421
# Epoch 14/200
# 27/27 [==============================] - 5s 169ms/step - loss: 0.7417 - acc: 0.5747 - val_loss: 0.7929 - val_acc: 0.3158
#
# Epoch 00014: val_acc did not improve from 0.68421
# Epoch 15/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.7839 - acc: 0.5458 - val_loss: 0.7732 - val_acc: 0.3158
#
# Epoch 00015: val_acc did not improve from 0.68421
# Epoch 16/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.7605 - acc: 0.5005 - val_loss: 0.8288 - val_acc: 0.3158
#
# Epoch 00016: val_acc did not improve from 0.68421
# Epoch 17/200
# 27/27 [==============================] - 5s 182ms/step - loss: 0.7898 - acc: 0.4171 - val_loss: 0.7590 - val_acc: 0.3158
#
# Epoch 00017: val_acc did not improve from 0.68421
# Epoch 18/200
# 27/27 [==============================] - 5s 173ms/step - loss: 0.7475 - acc: 0.5098 - val_loss: 0.7165 - val_acc: 0.6842
#
# Epoch 00018: val_acc did not improve from 0.68421
# Epoch 19/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.7410 - acc: 0.5283 - val_loss: 0.7620 - val_acc: 0.3684
#
# Epoch 00019: val_acc did not improve from 0.68421
# Epoch 20/200
# 27/27 [==============================] - 5s 175ms/step - loss: 0.7820 - acc: 0.4810 - val_loss: 0.7721 - val_acc: 0.3158
#
# Epoch 00020: val_acc did not improve from 0.68421
# Epoch 21/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.7545 - acc: 0.4727 - val_loss: 0.8348 - val_acc: 0.3158
#
# Epoch 00021: val_acc did not improve from 0.68421
# Epoch 22/200
# 27/27 [==============================] - 5s 175ms/step - loss: 0.7593 - acc: 0.5190 - val_loss: 0.7246 - val_acc: 0.7368
#
# Epoch 00022: val_acc improved from 0.68421 to 0.73684, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/MPRAGE/weights-augm-trial4-improvement-BEST.hdf5
# Epoch 23/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.7451 - acc: 0.4995 - val_loss: 0.7468 - val_acc: 0.3158
#
# Epoch 00023: val_acc did not improve from 0.73684
# Epoch 24/200
# 27/27 [==============================] - 5s 170ms/step - loss: 0.7372 - acc: 0.5098 - val_loss: 0.7367 - val_acc: 0.3684
#
# Epoch 00024: val_acc did not improve from 0.73684
# Epoch 25/200
# 27/27 [==============================] - 5s 170ms/step - loss: 0.7053 - acc: 0.5829 - val_loss: 0.8106 - val_acc: 0.3158
#
# Epoch 00025: val_acc did not improve from 0.73684
# Epoch 26/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.7594 - acc: 0.4542 - val_loss: 0.7202 - val_acc: 0.6316
#
# Epoch 00026: val_acc did not improve from 0.73684
# Epoch 27/200
# 27/27 [==============================] - 5s 171ms/step - loss: 0.7242 - acc: 0.6107 - val_loss: 0.7282 - val_acc: 0.4211
#
# Epoch 00027: val_acc did not improve from 0.73684
# Epoch 28/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.7201 - acc: 0.5644 - val_loss: 0.7735 - val_acc: 0.3158
#
# Epoch 00028: val_acc did not improve from 0.73684
# Epoch 29/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.7150 - acc: 0.5829 - val_loss: 0.7763 - val_acc: 0.3158
#
# Epoch 00029: val_acc did not improve from 0.73684
# Epoch 30/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.7074 - acc: 0.5747 - val_loss: 0.7171 - val_acc: 0.5263
#
# Epoch 00030: val_acc did not improve from 0.73684
# Epoch 31/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.6899 - acc: 0.6385 - val_loss: 0.7491 - val_acc: 0.4737
#
# Epoch 00031: val_acc did not improve from 0.73684
# Epoch 32/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.6801 - acc: 0.6107 - val_loss: 0.8078 - val_acc: 0.3684
#
# Epoch 00032: val_acc did not improve from 0.73684
# Epoch 33/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.6778 - acc: 0.5922 - val_loss: 0.7512 - val_acc: 0.5263
#
# Epoch 00033: val_acc did not improve from 0.73684
# Epoch 00033: early stopping
# Trial 5
# Epoch 1/200
# 27/27 [==============================] - 7s 243ms/step - loss: 1.3143 - acc: 0.4727 - val_loss: 0.8496 - val_acc: 0.6842
#
# Epoch 00001: val_acc improved from -inf to 0.68421, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/MPRAGE/weights-augm-trial5-improvement-BEST.hdf5
# Epoch 2/200
# 27/27 [==============================] - 4s 157ms/step - loss: 1.0155 - acc: 0.4634 - val_loss: 0.9853 - val_acc: 0.3158
#
# Epoch 00002: val_acc did not improve from 0.68421
# Epoch 3/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.9731 - acc: 0.5366 - val_loss: 1.0215 - val_acc: 0.3158
#
# Epoch 00003: val_acc did not improve from 0.68421
# Epoch 4/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.9187 - acc: 0.5366 - val_loss: 0.8511 - val_acc: 0.6842
#
# Epoch 00004: val_acc did not improve from 0.68421
# Epoch 5/200
# 27/27 [==============================] - 5s 170ms/step - loss: 1.0076 - acc: 0.4634 - val_loss: 0.8252 - val_acc: 0.6842
#
# Epoch 00005: val_acc did not improve from 0.68421
# Epoch 6/200
# 27/27 [==============================] - 5s 176ms/step - loss: 0.8887 - acc: 0.5283 - val_loss: 0.9631 - val_acc: 0.3158
#
# Epoch 00006: val_acc did not improve from 0.68421
# Epoch 7/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.8857 - acc: 0.5088 - val_loss: 0.9159 - val_acc: 0.3158
#
# Epoch 00007: val_acc did not improve from 0.68421
# Epoch 8/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.8902 - acc: 0.5273 - val_loss: 0.7360 - val_acc: 0.6842
#
# Epoch 00008: val_acc did not improve from 0.68421
# Epoch 9/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.8872 - acc: 0.5458 - val_loss: 0.7717 - val_acc: 0.7368
#
# Epoch 00009: val_acc improved from 0.68421 to 0.73684, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/MPRAGE/weights-augm-trial5-improvement-BEST.hdf5
# Epoch 10/200
# 27/27 [==============================] - 4s 155ms/step - loss: 0.9078 - acc: 0.3893 - val_loss: 0.8737 - val_acc: 0.3158
#
# Epoch 00010: val_acc did not improve from 0.73684
# Epoch 11/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.8389 - acc: 0.4820 - val_loss: 0.8298 - val_acc: 0.3158
#
# Epoch 00011: val_acc did not improve from 0.73684
# Epoch 12/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.8000 - acc: 0.5551 - val_loss: 0.7479 - val_acc: 0.7368
#
# Epoch 00012: val_acc did not improve from 0.73684
# Epoch 13/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.8031 - acc: 0.5644 - val_loss: 0.7809 - val_acc: 0.5263
#
# Epoch 00013: val_acc did not improve from 0.73684
# Epoch 14/200
# 27/27 [==============================] - 5s 171ms/step - loss: 0.7791 - acc: 0.6014 - val_loss: 0.9180 - val_acc: 0.3158
#
# Epoch 00014: val_acc did not improve from 0.73684
# Epoch 15/200
# 27/27 [==============================] - 5s 170ms/step - loss: 0.7732 - acc: 0.4810 - val_loss: 0.8654 - val_acc: 0.3158
#
# Epoch 00015: val_acc did not improve from 0.73684
# Epoch 16/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.7451 - acc: 0.5922 - val_loss: 0.8613 - val_acc: 0.3158
#
# Epoch 00016: val_acc did not improve from 0.73684
# Epoch 17/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.7482 - acc: 0.5644 - val_loss: 0.8378 - val_acc: 0.3684
#
# Epoch 00017: val_acc did not improve from 0.73684
# Epoch 18/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.7452 - acc: 0.5736 - val_loss: 0.8281 - val_acc: 0.4211
#
# Epoch 00018: val_acc did not improve from 0.73684
# Epoch 19/200
# 27/27 [==============================] - 5s 170ms/step - loss: 0.7299 - acc: 0.5922 - val_loss: 0.7212 - val_acc: 0.4737
#
# Epoch 00019: val_acc did not improve from 0.73684
# Epoch 20/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.7529 - acc: 0.5736 - val_loss: 0.7891 - val_acc: 0.5263
#
# Epoch 00020: val_acc did not improve from 0.73684
# Epoch 21/200
# 27/27 [==============================] - 5s 174ms/step - loss: 0.6809 - acc: 0.6849 - val_loss: 0.7976 - val_acc: 0.4737
#
# Epoch 00021: val_acc did not improve from 0.73684
# Epoch 22/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.7025 - acc: 0.6488 - val_loss: 0.7565 - val_acc: 0.5263
#
# Epoch 00022: val_acc did not improve from 0.73684
# Epoch 23/200
# 27/27 [==============================] - 5s 169ms/step - loss: 0.7161 - acc: 0.6385 - val_loss: 0.7400 - val_acc: 0.5263
#
# Epoch 00023: val_acc did not improve from 0.73684
# Epoch 24/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.6828 - acc: 0.6293 - val_loss: 0.9562 - val_acc: 0.4211
#
# Epoch 00024: val_acc did not improve from 0.73684
# Epoch 25/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.6939 - acc: 0.6941 - val_loss: 1.0050 - val_acc: 0.3158
#
# Epoch 00025: val_acc did not improve from 0.73684
# Epoch 26/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.6965 - acc: 0.6385 - val_loss: 0.9329 - val_acc: 0.3684
#
# Epoch 00026: val_acc did not improve from 0.73684
# Epoch 27/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.6613 - acc: 0.6581 - val_loss: 1.0117 - val_acc: 0.3684
#
# Epoch 00027: val_acc did not improve from 0.73684
# Epoch 28/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.6807 - acc: 0.6303 - val_loss: 0.7687 - val_acc: 0.4737
#
# Epoch 00028: val_acc did not improve from 0.73684
# Epoch 29/200
# 27/27 [==============================] - 5s 172ms/step - loss: 0.7026 - acc: 0.6859 - val_loss: 0.9969 - val_acc: 0.4211
#
# Epoch 00029: val_acc did not improve from 0.73684
# Epoch 30/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.6667 - acc: 0.6663 - val_loss: 0.8839 - val_acc: 0.4211
#
# Epoch 00030: val_acc did not improve from 0.73684
# Epoch 31/200
# 27/27 [==============================] - 4s 154ms/step - loss: 0.6681 - acc: 0.6571 - val_loss: 0.7945 - val_acc: 0.5263
#
# Epoch 00031: val_acc did not improve from 0.73684
# Epoch 32/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.6333 - acc: 0.6673 - val_loss: 0.9686 - val_acc: 0.3684
#
# Epoch 00032: val_acc did not improve from 0.73684
# Epoch 33/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.6652 - acc: 0.7044 - val_loss: 0.9213 - val_acc: 0.4737
#
# Epoch 00033: val_acc did not improve from 0.73684
# Epoch 34/200
# 27/27 [==============================] - 4s 155ms/step - loss: 0.6282 - acc: 0.7127 - val_loss: 0.8506 - val_acc: 0.4211
#
# Epoch 00034: val_acc did not improve from 0.73684
# Epoch 00034: early stopping
# Trial 6
# Epoch 1/200
# 27/27 [==============================] - 6s 237ms/step - loss: 1.0903 - acc: 0.5273 - val_loss: 0.8527 - val_acc: 0.6842
#
# Epoch 00001: val_acc improved from -inf to 0.68421, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/MPRAGE/weights-augm-trial6-improvement-BEST.hdf5
# Epoch 2/200
# 27/27 [==============================] - 4s 155ms/step - loss: 1.0035 - acc: 0.4902 - val_loss: 0.9170 - val_acc: 0.3158
#
# Epoch 00002: val_acc did not improve from 0.68421
# Epoch 3/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.8671 - acc: 0.5458 - val_loss: 0.9088 - val_acc: 0.3158
#
# Epoch 00003: val_acc did not improve from 0.68421
# Epoch 4/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.9868 - acc: 0.4727 - val_loss: 0.9181 - val_acc: 0.3158
#
# Epoch 00004: val_acc did not improve from 0.68421
# Epoch 5/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.9556 - acc: 0.5283 - val_loss: 0.8454 - val_acc: 0.3158
#
# Epoch 00005: val_acc did not improve from 0.68421
# Epoch 6/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.9297 - acc: 0.5088 - val_loss: 0.8413 - val_acc: 0.3158
#
# Epoch 00006: val_acc did not improve from 0.68421
# Epoch 7/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.8459 - acc: 0.6107 - val_loss: 0.8549 - val_acc: 0.3158
#
# Epoch 00007: val_acc did not improve from 0.68421
# Epoch 8/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.8597 - acc: 0.5005 - val_loss: 0.6940 - val_acc: 0.6842
#
# Epoch 00008: val_acc did not improve from 0.68421
# Epoch 9/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.8089 - acc: 0.4542 - val_loss: 0.7996 - val_acc: 0.3684
#
# Epoch 00009: val_acc did not improve from 0.68421
# Epoch 10/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.7997 - acc: 0.5098 - val_loss: 0.7768 - val_acc: 0.3684
#
# Epoch 00010: val_acc did not improve from 0.68421
# Epoch 11/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.8218 - acc: 0.5376 - val_loss: 0.7884 - val_acc: 0.3158
#
# Epoch 00011: val_acc did not improve from 0.68421
# Epoch 12/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.8141 - acc: 0.4634 - val_loss: 0.8079 - val_acc: 0.3158
#
# Epoch 00012: val_acc did not improve from 0.68421
# Epoch 13/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.8059 - acc: 0.4810 - val_loss: 0.7377 - val_acc: 0.6842
#
# Epoch 00013: val_acc did not improve from 0.68421
# Epoch 14/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.7513 - acc: 0.5376 - val_loss: 0.7291 - val_acc: 0.6316
#
# Epoch 00014: val_acc did not improve from 0.68421
# Epoch 15/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.7466 - acc: 0.5098 - val_loss: 0.7347 - val_acc: 0.6316
#
# Epoch 00015: val_acc did not improve from 0.68421
# Epoch 16/200
# 27/27 [==============================] - 4s 154ms/step - loss: 0.7461 - acc: 0.6025 - val_loss: 0.7843 - val_acc: 0.3158
#
# Epoch 00016: val_acc did not improve from 0.68421
# Epoch 17/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.7693 - acc: 0.5644 - val_loss: 0.7329 - val_acc: 0.7895
#
# Epoch 00017: val_acc improved from 0.68421 to 0.78947, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/MPRAGE/weights-augm-trial6-improvement-BEST.hdf5
# Epoch 18/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.7827 - acc: 0.4727 - val_loss: 0.7386 - val_acc: 0.6316
#
# Epoch 00018: val_acc did not improve from 0.78947
# Epoch 19/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.7478 - acc: 0.5839 - val_loss: 0.7736 - val_acc: 0.3684
#
# Epoch 00019: val_acc did not improve from 0.78947
# Epoch 20/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.7603 - acc: 0.4820 - val_loss: 0.7358 - val_acc: 0.5263
#
# Epoch 00020: val_acc did not improve from 0.78947
# Epoch 21/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.7593 - acc: 0.5376 - val_loss: 0.8947 - val_acc: 0.3158
#
# Epoch 00021: val_acc did not improve from 0.78947
# Epoch 22/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.7099 - acc: 0.6385 - val_loss: 0.8254 - val_acc: 0.3158
#
# Epoch 00022: val_acc did not improve from 0.78947
# Epoch 23/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.7142 - acc: 0.6293 - val_loss: 0.6993 - val_acc: 0.5263
#
# Epoch 00023: val_acc did not improve from 0.78947
# Epoch 00023: early stopping
# Trial 7
# Epoch 1/200
# 27/27 [==============================] - 7s 264ms/step - loss: 1.1337 - acc: 0.4820 - val_loss: 0.9244 - val_acc: 0.3158
#
# Epoch 00001: val_acc improved from -inf to 0.31579, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/MPRAGE/weights-augm-trial7-improvement-BEST.hdf5
# Epoch 2/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.9800 - acc: 0.6025 - val_loss: 0.8827 - val_acc: 0.6842
#
# Epoch 00002: val_acc improved from 0.31579 to 0.68421, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/MPRAGE/weights-augm-trial7-improvement-BEST.hdf5
# Epoch 3/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.9918 - acc: 0.5366 - val_loss: 1.1260 - val_acc: 0.3158
#
# Epoch 00003: val_acc did not improve from 0.68421
# Epoch 4/200
# 27/27 [==============================] - 4s 164ms/step - loss: 1.0912 - acc: 0.4717 - val_loss: 0.9502 - val_acc: 0.3158
#
# Epoch 00004: val_acc did not improve from 0.68421
# Epoch 5/200
# 27/27 [==============================] - 4s 162ms/step - loss: 1.0046 - acc: 0.4449 - val_loss: 0.8752 - val_acc: 0.3158
#
# Epoch 00005: val_acc did not improve from 0.68421
# Epoch 6/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.8861 - acc: 0.5736 - val_loss: 0.8350 - val_acc: 0.6842
#
# Epoch 00006: val_acc did not improve from 0.68421
# Epoch 7/200
# 27/27 [==============================] - 5s 173ms/step - loss: 0.9205 - acc: 0.4727 - val_loss: 0.9390 - val_acc: 0.3158
#
# Epoch 00007: val_acc did not improve from 0.68421
# Epoch 8/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.8940 - acc: 0.4624 - val_loss: 0.8326 - val_acc: 0.3158
#
# Epoch 00008: val_acc did not improve from 0.68421
# Epoch 9/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.8069 - acc: 0.5561 - val_loss: 0.8626 - val_acc: 0.3158
#
# Epoch 00009: val_acc did not improve from 0.68421
# Epoch 10/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.8632 - acc: 0.5366 - val_loss: 0.8190 - val_acc: 0.3158
#
# Epoch 00010: val_acc did not improve from 0.68421
# Epoch 11/200
# 27/27 [==============================] - 4s 154ms/step - loss: 0.7743 - acc: 0.5366 - val_loss: 3.7211 - val_acc: 0.3158
#
# Epoch 00011: val_acc did not improve from 0.68421
# Epoch 12/200
# 27/27 [==============================] - 5s 171ms/step - loss: 0.9315 - acc: 0.5458 - val_loss: 0.9228 - val_acc: 0.3158
#
# Epoch 00012: val_acc did not improve from 0.68421
# Epoch 13/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.8212 - acc: 0.5551 - val_loss: 0.7921 - val_acc: 0.5789
#
# Epoch 00013: val_acc did not improve from 0.68421
# Epoch 14/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.8783 - acc: 0.4542 - val_loss: 0.7905 - val_acc: 0.3158
#
# Epoch 00014: val_acc did not improve from 0.68421
# Epoch 15/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.8067 - acc: 0.5088 - val_loss: 0.8013 - val_acc: 0.3158
#
# Epoch 00015: val_acc did not improve from 0.68421
# Epoch 16/200
# 27/27 [==============================] - 4s 154ms/step - loss: 0.7944 - acc: 0.5644 - val_loss: 0.8091 - val_acc: 0.3158
#
# Epoch 00016: val_acc did not improve from 0.68421
# Epoch 17/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.7699 - acc: 0.5088 - val_loss: 0.8262 - val_acc: 0.3158
#
# Epoch 00017: val_acc did not improve from 0.68421
# Epoch 18/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.8034 - acc: 0.3893 - val_loss: 0.7514 - val_acc: 0.8421
#
# Epoch 00018: val_acc improved from 0.68421 to 0.84211, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/MPRAGE/weights-augm-trial7-improvement-BEST.hdf5
# Epoch 19/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.7948 - acc: 0.5376 - val_loss: 0.7587 - val_acc: 0.5789
#
# Epoch 00019: val_acc did not improve from 0.84211
# Epoch 20/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.7625 - acc: 0.5273 - val_loss: 0.7802 - val_acc: 0.3158
#
# Epoch 00020: val_acc did not improve from 0.84211
# Epoch 21/200
# 27/27 [==============================] - 4s 154ms/step - loss: 0.7493 - acc: 0.5644 - val_loss: 0.7706 - val_acc: 0.3158
#
# Epoch 00021: val_acc did not improve from 0.84211
# Epoch 22/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.7662 - acc: 0.5273 - val_loss: 0.8576 - val_acc: 0.3158
#
# Epoch 00022: val_acc did not improve from 0.84211
# Epoch 23/200
# 27/27 [==============================] - 4s 153ms/step - loss: 0.7862 - acc: 0.4542 - val_loss: 0.8053 - val_acc: 0.3158
#
# Epoch 00023: val_acc did not improve from 0.84211
# Epoch 24/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.7621 - acc: 0.5180 - val_loss: 0.7607 - val_acc: 0.3158
#
# Epoch 00024: val_acc did not improve from 0.84211
# Epoch 25/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.7544 - acc: 0.5366 - val_loss: 0.7913 - val_acc: 0.3158
#
# Epoch 00025: val_acc did not improve from 0.84211
# Epoch 26/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.7357 - acc: 0.5829 - val_loss: 0.7650 - val_acc: 0.3158
#
# Epoch 00026: val_acc did not improve from 0.84211
# Epoch 27/200
# 27/27 [==============================] - 5s 172ms/step - loss: 0.7412 - acc: 0.5190 - val_loss: 0.7690 - val_acc: 0.3158
#
# Epoch 00027: val_acc did not improve from 0.84211
# Epoch 28/200
# 27/27 [==============================] - 5s 174ms/step - loss: 0.7369 - acc: 0.5005 - val_loss: 0.7398 - val_acc: 0.3684
#
# ...
#
# Epoch 00033: val_acc did not improve from 0.84211
# Epoch 34/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.7190 - acc: 0.5376 - val_loss: 0.7500 - val_acc: 0.3158
#
# Epoch 00034: val_acc did not improve from 0.84211
# Epoch 35/200
# 27/27 [==============================] - 4s 155ms/step - loss: 0.7075 - acc: 0.5644 - val_loss: 0.7489 - val_acc: 0.3158
#
# Epoch 00035: val_acc did not improve from 0.84211
# Epoch 36/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.7092 - acc: 0.5736 - val_loss: 0.7408 - val_acc: 0.3684
#
# Epoch 00036: val_acc did not improve from 0.84211
# Epoch 37/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.7019 - acc: 0.6014 - val_loss: 0.7403 - val_acc: 0.3684
#
# Epoch 00037: val_acc did not improve from 0.84211
# Epoch 38/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.6948 - acc: 0.5469 - val_loss: 0.7438 - val_acc: 0.3684
#
# Epoch 00038: val_acc did not improve from 0.84211
# Epoch 39/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.7003 - acc: 0.6200 - val_loss: 0.7705 - val_acc: 0.3158
#
# Epoch 00039: val_acc did not improve from 0.84211
# Epoch 40/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.6999 - acc: 0.5922 - val_loss: 0.8032 - val_acc: 0.3158
#
# Epoch 00040: val_acc did not improve from 0.84211
# Epoch 41/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.7002 - acc: 0.5829 - val_loss: 0.7047 - val_acc: 0.6316
#
# Epoch 00041: val_acc did not improve from 0.84211
# Epoch 42/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.6883 - acc: 0.6117 - val_loss: 0.7111 - val_acc: 0.6316
#
# Epoch 00042: val_acc did not improve from 0.84211
# Epoch 43/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.6869 - acc: 0.6385 - val_loss: 0.7579 - val_acc: 0.4737
#
# Epoch 00043: val_acc did not improve from 0.84211
# Epoch 44/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.6627 - acc: 0.6488 - val_loss: 0.7618 - val_acc: 0.4737
#
# Epoch 00044: val_acc did not improve from 0.84211
# Epoch 45/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.6645 - acc: 0.6385 - val_loss: 0.7284 - val_acc: 0.5263
#
# Epoch 00045: val_acc did not improve from 0.84211
# Epoch 46/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.6446 - acc: 0.6766 - val_loss: 0.8025 - val_acc: 0.4737
#
# Epoch 00046: val_acc did not improve from 0.84211
# Epoch 47/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.6827 - acc: 0.6581 - val_loss: 0.7979 - val_acc: 0.5263
#
# Epoch 00047: val_acc did not improve from 0.84211
# Epoch 48/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.6598 - acc: 0.6663 - val_loss: 0.7334 - val_acc: 0.5789
#
# Epoch 00048: val_acc did not improve from 0.84211
# Epoch 49/200
# 27/27 [==============================] - 5s 169ms/step - loss: 0.6644 - acc: 0.6478 - val_loss: 0.7075 - val_acc: 0.5263
#
# Epoch 00049: val_acc did not improve from 0.84211
# Epoch 50/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.6574 - acc: 0.7127 - val_loss: 0.7421 - val_acc: 0.5263
#
# Epoch 00050: val_acc did not improve from 0.84211
# Epoch 51/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.6442 - acc: 0.6673 - val_loss: 0.7216 - val_acc: 0.5263
#
# Epoch 00051: val_acc did not improve from 0.84211
# Epoch 52/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.6584 - acc: 0.6210 - val_loss: 0.7918 - val_acc: 0.4737
#
# Epoch 00052: val_acc did not improve from 0.84211
# Epoch 53/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.6334 - acc: 0.7127 - val_loss: 0.7290 - val_acc: 0.4737
#
# Epoch 00053: val_acc did not improve from 0.84211
# Epoch 54/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.6405 - acc: 0.7127 - val_loss: 1.0129 - val_acc: 0.3684
#
# Epoch 00054: val_acc did not improve from 0.84211
# Epoch 55/200
# 27/27 [==============================] - 4s 154ms/step - loss: 0.6722 - acc: 0.6849 - val_loss: 0.7083 - val_acc: 0.4737
#
# Epoch 00055: val_acc did not improve from 0.84211
# Epoch 56/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.6513 - acc: 0.6025 - val_loss: 0.8548 - val_acc: 0.5263
#
# Epoch 00056: val_acc did not improve from 0.84211
# Epoch 00056: early stopping
# Trial 8
# Epoch 1/200
# 27/27 [==============================] - 7s 252ms/step - loss: 1.0943 - acc: 0.5469 - val_loss: 0.8714 - val_acc: 0.6842
#
# Epoch 00001: val_acc improved from -inf to 0.68421, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/MPRAGE/weights-augm-trial8-improvement-BEST.hdf5
# Epoch 2/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.9836 - acc: 0.4717 - val_loss: 0.8934 - val_acc: 0.3158
#
# Epoch 00002: val_acc did not improve from 0.68421
# Epoch 3/200
# 27/27 [==============================] - 4s 153ms/step - loss: 0.9331 - acc: 0.5088 - val_loss: 0.9619 - val_acc: 0.3158
#
# Epoch 00003: val_acc did not improve from 0.68421
# Epoch 4/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.9835 - acc: 0.5366 - val_loss: 0.9097 - val_acc: 0.3158
#
# Epoch 00004: val_acc did not improve from 0.68421
# Epoch 5/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.9096 - acc: 0.4717 - val_loss: 0.9766 - val_acc: 0.3158
#
# Epoch 00005: val_acc did not improve from 0.68421
# Epoch 6/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.8892 - acc: 0.4912 - val_loss: 0.7527 - val_acc: 0.6842
#
# Epoch 00006: val_acc did not improve from 0.68421
# Epoch 7/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.9239 - acc: 0.4356 - val_loss: 0.7711 - val_acc: 0.7368
#
# Epoch 00007: val_acc improved from 0.68421 to 0.73684, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/MPRAGE/weights-augm-trial8-improvement-BEST.hdf5
# Epoch 8/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.8152 - acc: 0.6014 - val_loss: 0.7967 - val_acc: 0.5789
#
# Epoch 00008: val_acc did not improve from 0.73684
# Epoch 9/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.8232 - acc: 0.4912 - val_loss: 0.8479 - val_acc: 0.3158
#
# Epoch 00009: val_acc did not improve from 0.73684
# Epoch 10/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.7985 - acc: 0.5654 - val_loss: 0.7770 - val_acc: 0.6316
#
# Epoch 00010: val_acc did not improve from 0.73684
# Epoch 11/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.7919 - acc: 0.5273 - val_loss: 0.9993 - val_acc: 0.3158
#
# Epoch 00011: val_acc did not improve from 0.73684
# Epoch 12/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.7951 - acc: 0.5829 - val_loss: 0.7837 - val_acc: 0.4737
#
# Epoch 00012: val_acc did not improve from 0.73684
# Epoch 13/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.8337 - acc: 0.4264 - val_loss: 0.7878 - val_acc: 0.5789
#
# Epoch 00013: val_acc did not improve from 0.73684
# Epoch 14/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.7693 - acc: 0.5829 - val_loss: 0.8463 - val_acc: 0.3158
#
# Epoch 00014: val_acc did not improve from 0.73684
# Epoch 15/200
# 27/27 [==============================] - 5s 169ms/step - loss: 0.7567 - acc: 0.5469 - val_loss: 0.8334 - val_acc: 0.4211
#
# Epoch 00015: val_acc did not improve from 0.73684
# Epoch 16/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.7881 - acc: 0.5190 - val_loss: 0.7856 - val_acc: 0.4737
#
# Epoch 00016: val_acc did not improve from 0.73684
# Epoch 17/200
# 27/27 [==============================] - 4s 155ms/step - loss: 0.7308 - acc: 0.6025 - val_loss: 0.8303 - val_acc: 0.4211
#
# Epoch 00017: val_acc did not improve from 0.73684
# Epoch 18/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.7106 - acc: 0.6571 - val_loss: 0.8206 - val_acc: 0.5263
#
# Epoch 00018: val_acc did not improve from 0.73684
# Epoch 19/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.7354 - acc: 0.6303 - val_loss: 0.9395 - val_acc: 0.3158
#
# Epoch 00019: val_acc did not improve from 0.73684
# Epoch 20/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.7195 - acc: 0.6117 - val_loss: 0.7609 - val_acc: 0.5263
#
# Epoch 00020: val_acc did not improve from 0.73684
# Epoch 21/200
# 27/27 [==============================] - 5s 178ms/step - loss: 0.7418 - acc: 0.5654 - val_loss: 0.9626 - val_acc: 0.3684
#
# Epoch 00021: val_acc did not improve from 0.73684
# Epoch 00021: early stopping
# Trial 9
# Epoch 1/200
# 27/27 [==============================] - 7s 262ms/step - loss: 1.0120 - acc: 0.5190 - val_loss: 0.8484 - val_acc: 0.6842
#
# Epoch 00001: val_acc improved from -inf to 0.68421, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/MPRAGE/weights-augm-trial9-improvement-BEST.hdf5
# Epoch 2/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.9916 - acc: 0.4717 - val_loss: 0.9326 - val_acc: 0.3158
#
# Epoch 00002: val_acc did not improve from 0.68421
# Epoch 3/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.8908 - acc: 0.5088 - val_loss: 0.9053 - val_acc: 0.3158
#
# Epoch 00003: val_acc did not improve from 0.68421
# Epoch 4/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.8451 - acc: 0.5932 - val_loss: 0.8592 - val_acc: 0.3158
#
# Epoch 00004: val_acc did not improve from 0.68421
# Epoch 5/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.8818 - acc: 0.4439 - val_loss: 0.8481 - val_acc: 0.3158
#
# Epoch 00005: val_acc did not improve from 0.68421
# Epoch 6/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.8362 - acc: 0.4634 - val_loss: 0.9163 - val_acc: 0.3158
#
# Epoch 00006: val_acc did not improve from 0.68421
# Epoch 7/200
# 27/27 [==============================] - 5s 177ms/step - loss: 0.8441 - acc: 0.5644 - val_loss: 0.8098 - val_acc: 0.3158
#
# Epoch 00007: val_acc did not improve from 0.68421
# Epoch 8/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.8898 - acc: 0.4727 - val_loss: 0.7549 - val_acc: 0.6842
#
# Epoch 00008: val_acc did not improve from 0.68421
# Epoch 9/200
# 27/27 [==============================] - 5s 170ms/step - loss: 0.8399 - acc: 0.5190 - val_loss: 0.7852 - val_acc: 0.3158
#
# Epoch 00009: val_acc did not improve from 0.68421
# Epoch 10/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.8324 - acc: 0.4727 - val_loss: 0.7647 - val_acc: 0.6842
#
# Epoch 00010: val_acc did not improve from 0.68421
# Epoch 11/200
# 27/27 [==============================] - 5s 183ms/step - loss: 0.7991 - acc: 0.6025 - val_loss: 0.9010 - val_acc: 0.3158
#
# Epoch 00011: val_acc did not improve from 0.68421
# Epoch 12/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.8098 - acc: 0.5180 - val_loss: 0.7534 - val_acc: 0.5263
#
# Epoch 00012: val_acc did not improve from 0.68421
# Epoch 13/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.8156 - acc: 0.4531 - val_loss: 0.7678 - val_acc: 0.3158
#
# Epoch 00013: val_acc did not improve from 0.68421
# Epoch 14/200
# 27/27 [==============================] - 5s 171ms/step - loss: 0.7801 - acc: 0.5098 - val_loss: 0.8094 - val_acc: 0.3158
#
# Epoch 00014: val_acc did not improve from 0.68421
# Epoch 15/200
# 27/27 [==============================] - 4s 154ms/step - loss: 0.7517 - acc: 0.5458 - val_loss: 0.7506 - val_acc: 0.5263
#
# Epoch 00015: val_acc did not improve from 0.68421
# Epoch 16/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.7386 - acc: 0.5839 - val_loss: 0.6394 - val_acc: 0.7368
#
# Epoch 00016: val_acc improved from 0.68421 to 0.73684, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/MPRAGE/weights-augm-trial9-improvement-BEST.hdf5
# Epoch 17/200
# 27/27 [==============================] - 4s 153ms/step - loss: 0.7833 - acc: 0.5273 - val_loss: 0.8603 - val_acc: 0.3158
#
# Epoch 00017: val_acc did not improve from 0.73684
# Epoch 18/200
# 27/27 [==============================] - 5s 174ms/step - loss: 0.7580 - acc: 0.5644 - val_loss: 0.6599 - val_acc: 0.7368
#
# Epoch 00018: val_acc did not improve from 0.73684
# Epoch 19/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.7513 - acc: 0.4995 - val_loss: 0.7954 - val_acc: 0.3158
#
# Epoch 00019: val_acc did not improve from 0.73684
# Epoch 20/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.7336 - acc: 0.5458 - val_loss: 0.8340 - val_acc: 0.3158
#
# Epoch 00020: val_acc did not improve from 0.73684
# Epoch 21/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.7426 - acc: 0.5736 - val_loss: 0.8327 - val_acc: 0.3158
#
# Epoch 00021: val_acc did not improve from 0.73684
# Epoch 22/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.7100 - acc: 0.5839 - val_loss: 0.7684 - val_acc: 0.3158
#
# Epoch 00022: val_acc did not improve from 0.73684
# Epoch 23/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.7040 - acc: 0.6107 - val_loss: 0.8066 - val_acc: 0.3158
#
# Epoch 00023: val_acc did not improve from 0.73684
# Epoch 24/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.6938 - acc: 0.6478 - val_loss: 0.7295 - val_acc: 0.5789
#
# Epoch 00024: val_acc did not improve from 0.73684
# Epoch 25/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.6967 - acc: 0.6293 - val_loss: 0.8016 - val_acc: 0.4737
#
# Epoch 00025: val_acc did not improve from 0.73684
# Epoch 26/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.7004 - acc: 0.6025 - val_loss: 0.7559 - val_acc: 0.6316
#
# Epoch 00026: val_acc did not improve from 0.73684
# Epoch 27/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.6870 - acc: 0.6025 - val_loss: 0.7291 - val_acc: 0.4737
#
# Epoch 00027: val_acc did not improve from 0.73684
# Epoch 28/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.6744 - acc: 0.6293 - val_loss: 0.7325 - val_acc: 0.5789
#
# Epoch 00028: val_acc did not improve from 0.73684
# Epoch 29/200
# 27/27 [==============================] - 5s 180ms/step - loss: 0.6705 - acc: 0.6663 - val_loss: 0.8529 - val_acc: 0.4211
#
# Epoch 00029: val_acc did not improve from 0.73684
# Epoch 30/200
# 27/27 [==============================] - 4s 154ms/step - loss: 0.6422 - acc: 0.7127 - val_loss: 0.9054 - val_acc: 0.4211
#
# Epoch 00030: val_acc did not improve from 0.73684
# Epoch 31/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.6562 - acc: 0.6756 - val_loss: 1.1424 - val_acc: 0.3684
#
# Epoch 00031: val_acc did not improve from 0.73684
# Epoch 00031: early stopping
# Training Time: 0.0h:25.0m:50.87482810020447s
# Validation final accuracies:
#  [0.47368421209485906, 0.42105263314749064, 0.3684210542001222, 0.3157894736842105, 0.5263157910422275, 0.42105263314749064, 0.5263157926107708, 0.5263157910422275, 0.3684210542001222, 0.3684210542001222]
# Validation final accuracies mean: 0.4315789489369643
# Validation best accuracies:
#  [0.6842105263157895, 0.6842105263157895, 0.6842105263157895, 0.6842105294528761, 0.7368421052631579, 0.7368421052631579, 0.7894736842105263, 0.8421052631578947, 0.7368421052631579, 0.7368421052631579]
# Validation best accuracies mean: 0.7315789476821296
# Validation balanced accuracies:
#  [0.5705128205128205, 0.5769230769230769, 0.5384615384615384, 0.5, 0.6538461538461539, 0.4423076923076923, 0.47435897435897434, 0.6538461538461539, 0.5384615384615384, 0.5384615384615384]
# Validation balanced accuracies mean: 0.5487179487179488
# Validation final sensitivities:
#  [0.8333333333333334, 1.0, 1.0, 1.0, 1.0, 0.5, 0.3333333333333333, 1.0, 1.0, 1.0]
# Validation final sensitivities' mean: 0.8666666666666666
# Validation final specificities:
#  [0.3076923076923077, 0.15384615384615385, 0.07692307692307693, 0.0, 0.3076923076923077, 0.38461538461538464, 0.6153846153846154, 0.3076923076923077, 0.07692307692307693, 0.07692307692307693]
# Validation final specificities' mean: 0.23076923076923084

# %%
training_time = time.time() - start_time

# %% [markdown]
# # Evaluation

# %%
weights = ["weights-augm-trial%i-improvement-BEST.hdf5"%i for i in range(num_trials)]

# %%
# load holdout set
test_loader = CISDataset(X_holdout, y_holdout, transform=[intensity], batch_size=1, shuffle=False)

# %%
accuracies = []
balanced_accuracies = []
sensitivities = []
specificities = []
auc_scores = []
tprs = []
mean_fpr = np.linspace(0, 1, 100)

plt.figure(figsize=(10, 8))

for fold, weight in enumerate(weights):
    print("Fold {}".format(fold))
    model = load_model(model_path)
    model_dir = os.path.join(result_dir, weight)
    model.load_weights(model_dir)
    
    opti = Adam(lr=lr, decay=lr_decay)
    model.compile(optimizer=opti,
              loss='binary_crossentropy',
              metrics=['accuracy'])
    
    # Evaluate
    res = model.evaluate_generator(test_loader)
    y_pred = model.predict_generator(test_loader)
    bal_acc = balanced_accuracy(y_holdout, y_pred>0.5)
    sens = sensitivity(y_holdout, y_pred>0.5)
    spec = specificity(y_holdout, y_pred>0.5)
    roc_auc = roc_auc_score(y_holdout, y_pred)
    fpr, tpr, thresholds = roc_curve(y_holdout, y_pred)   
    # Store results
    accuracies.append(res[1])
    balanced_accuracies.append(bal_acc)
    sensitivities.append(sens)
    specificities.append(spec)
    auc_scores.append(roc_auc)
    tprs.append(interp(mean_fpr, fpr, tpr))
    tprs[-1][0] = 0.0
    # Print results
    print("Model accuracy {:.2f} %".format(res[1]*100))
    print("Balanced accuracy {:.2f} %".format(bal_acc*100))
    print("Sensitivity {:.2f} %".format(sens*100))
    print("Specificity {:.2f} %".format(spec*100))
    print("Area Under the Receiver Operating Curve (ROC AUC score) {:.2f}".format(roc_auc*100))
    plt.plot(fpr, tpr, lw=1, alpha=0.3,
             label='ROC trial %d (AUC = %0.2f)' % (fold, roc_auc))
    
print("######## Final results ########")
print("Accuracy mean {:.2f} %".format(np.mean(accuracies)*100))
print("Balanced accuracy mean {:.2f} %".format(np.mean(balanced_accuracies)*100))
print("Sensitivity mean {:.2f} %".format(np.mean(sensitivities)*100))
print("Specificity mean {:.2f} %".format(np.mean(specificities)*100))
print("Mean ROC AUC score {:.2f}".format(np.mean(auc_scores)*100))

# Plot ROC Curves
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
         label='Chance', alpha=.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
#assert(mean_auc == np.mean(auc_scores))
std_auc = np.std(auc_scores)
plt.plot(mean_fpr, mean_tpr, color='b',
         label=r'Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (np.mean(auc_scores), std_auc),
         lw=2, alpha=.8)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
plt.fill_between(mean_fpr, tprs_lower, tprs_upper, color='grey', alpha=.2,
                 label=r'$\pm$ 1 std. dev.')

plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
# Out:
# Fold 0
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()
# Model accuracy 43.48 %
# Balanced accuracy 50.00 %
# Sensitivity 0.00 %
# Specificity 100.00 %
# Area Under the Receiver Operating Curve (ROC AUC score) 48.46
# Fold 1
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()
# Model accuracy 43.48 %
# Balanced accuracy 50.00 %
# Sensitivity 0.00 %
# Specificity 100.00 %
# Area Under the Receiver Operating Curve (ROC AUC score) 76.15
# Fold 2
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()
# Model accuracy 43.48 %
# Balanced accuracy 50.00 %
# Sensitivity 0.00 %
# Specificity 100.00 %
# Area Under the Receiver Operating Curve (ROC AUC score) 64.62
# Fold 3
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()
# Model accuracy 69.57 %
# Balanced accuracy 73.08 %
# Sensitivity 46.15 %
# Specificity 100.00 %
# Area Under the Receiver Operating Curve (ROC AUC score) 81.54
# Fold 4
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()
# Model accuracy 73.91 %
# Balanced accuracy 74.62 %
# Sensitivity 69.23 %
# Specificity 80.00 %
# Area Under the Receiver Operating Curve (ROC AUC score) 75.38
# Fold 5
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()
# Model accuracy 60.87 %
# Balanced accuracy 65.38 %
# Sensitivity 30.77 %
# Specificity 100.00 %
# Area Under the Receiver Operating Curve (ROC AUC score) 84.62
# Fold 6
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()
# Model accuracy 56.52 %
# Balanced accuracy 61.54 %
# Sensitivity 23.08 %
# Specificity 100.00 %
# Area Under the Receiver Operating Curve (ROC AUC score) 71.54
# Fold 7
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()
# Model accuracy 65.22 %
# Balanced accuracy 68.08 %
# Sensitivity 46.15 %
# Specificity 90.00 %
# Area Under the Receiver Operating Curve (ROC AUC score) 64.62
# Fold 8
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()
# Model accuracy 43.48 %
# Balanced accuracy 50.00 %
# Sensitivity 0.00 %
# Specificity 100.00 %
# Area Under the Receiver Operating Curve (ROC AUC score) 73.85
# Fold 9
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()
# Model accuracy 47.83 %
# Balanced accuracy 53.85 %
# Sensitivity 7.69 %
# Specificity 100.00 %
# Area Under the Receiver Operating Curve (ROC AUC score) 83.08
# ######## Final results ########
# Accuracy mean 54.78 %
# Balanced accuracy mean 59.65 %
# Sensitivity mean 22.31 %
# Specificity mean 97.00 %
# Mean ROC AUC score 72.38

# %%
total_time = time.time() - start_time

# %%
print("Training Time: {}h:{}m:{}s".format(
            training_time//3600, (training_time//60)%60, training_time%60))
print("Total time elapsed: {}h:{}m:{}s".format(
            total_time//3600, (total_time//60)%60, total_time%60))
# Out:
# Training Time: 0.0h:25.0m:50.888054609298706s
# Total time elapsed: 0.0h:27.0m:49.539677143096924s

# %%
quit()
