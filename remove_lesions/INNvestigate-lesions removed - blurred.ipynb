# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import h5py

import innvestigate

from keras.models import load_model
from keras import backend as K
from keras.utils import Sequence

from utils import load_nifti, normalize_float, IntensityRescale
from config import *
# Out:
# Using TensorFlow backend.

# %%
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.gpu_options.visible_device_list = "5"
set_session(tf.Session(config=config))

# %%
zero_one_normalize = True
dtype = np.float32
z_factor = 0.525
result_dir = "/analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/lesions_removed_blurred/"

# %%
# load hdf5 files and extract columns
train_h5 = h5py.File('/analysis/share/Ritter/MS/CIS/train_dataset.h5', 'r')
holdout_h5 = h5py.File('/analysis/share/Ritter/MS/CIS/holdout_dataset.h5', 'r')

X_train, y_train = train_h5['X'], train_h5['y']
X_holdout, y_holdout = holdout_h5['X'], holdout_h5['y']

train_lesions_h5 = h5py.File('/analysis/share/Ritter/MS/CIS/train_dataset_lesions.h5', 'r')
holdout_lesions_h5 = h5py.File('/analysis/share/Ritter/MS/CIS/holdout_dataset_lesions.h5', 'r')

lesion_masks_train = train_lesions_h5['masks']
lesion_masks_holdout = holdout_lesions_h5['masks']

# %%
print("Total datset length: {}".format(len(y_train)))
print("Number of healthy controls: {}".format(len(np.array(y_train)[np.array(y_train)==0.])))
print("Number of MS patients: {}".format(len(np.array(y_train)[np.array(y_train)==1.])))
# Out:
# Total datset length: 124
# Number of healthy controls: 61
# Number of MS patients: 63

# %%
class CISDataset(Sequence):
    def __init__(self, X, y, transform=None, batch_size=4, z_factor=None, shuffle=True, mask=None):
        self.X = X
        self.y = y
        self.transform = transform
        self.batch_size = batch_size
        self.z_factor = z_factor
        self.shuffle = shuffle
        self.mask = mask
        
    def __len__(self):
        return int(np.ceil(len(self.y)/self.batch_size))
    
    def __getitem__(self, idx):
        # add BET
        image = np.expand_dims(self.X[idx * self.batch_size:(idx + 1) * self.batch_size],5)
        #label = np.array((batch_idx['label'] == "MS")* 1, dtype=np.int8) 
        label = np.array(self.y[idx * self.batch_size:(idx + 1) * self.batch_size], dtype=np.int8)
        
        if self.mask is not None:
            for i in range(image.shape[0]):
                image[i] *= self.mask
        
        for transformation in self.transform:
            image = transformation(image)
        
        return image, label
    
    def on_epoch_end(self):
        if self.shuffle:
            self.X, self.y = shuffle(self.X, self.y)

# %% [markdown]
# ## Load mask and reformat

# %%
mask_path = "/data/Ritter/MS/Test/total_lesion_mask_blurred.nii.gz"

# %%
mask = load_nifti(mask_path, z_factor=z_factor)
mask = np.expand_dims(mask, 4)
# Out:
# /home/fabiane/.local/lib/python3.6/site-packages/scipy/ndimage/interpolation.py:583: UserWarning: From scipy 0.13.0, the output shape of zoom() is calculated with round() instead of int() - for these inputs the size of the returned array has changed.
#   "the returned array has changed.", UserWarning)
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.imshow(mask[:,:,48, 0], cmap='gray')
plt.subplot(1, 2, 2)
plt.hist(mask.flatten())
plt.show()

# %%
# after zooming return to binary format
mask[np.where(mask>0.5)] = 1.
mask[np.where(mask<=0.5)] = 0.

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.imshow(mask[:,:,48, 0], cmap='gray')
plt.subplot(1, 2, 2)
plt.hist(mask.flatten())
plt.show()

# %% [markdown]
# ## Make dataset

# %%
intensity = IntensityRescale(masked=False)

# %%
if zero_one_normalize:
    cis_data = CISDataset(X_train, y_train, transform=[intensity], batch_size=4, mask=mask)
else:
    cis_data = CISDataset(X_train, y_train, batch_size=4, mask=mask)

# %%
plt.figure()
plt.title("Normalized between zero and 1")
plt.hist(cis_data[4][0][0].flatten())
plt.show()
# Out:
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()

# %%
plt.figure()
plt.title("Scan image")
plt.imshow(np.squeeze(cis_data[4][0][0])[:,:,42], cmap='gray')
plt.show()
# Out:
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()

# %% [markdown]
# # Model

# %%
def init_model(path, finetune=True, up_to=7):
    model = load_model(path)
    model.load_weights(path)
    if finetune:
        for layer in model.layers[:up_to]:
            layer.trainable = False
    return model

# %%
# load model weights
#model_path = "/analysis/share/Ritter/models/fabi/ADNI/pretraining_paper/model.h5"
model_path = "/analysis/share/Ritter/models/fabi/ADNI/pretraining_paper/model_trial_6.h5"
model = init_model(model_path, finetune=False, up_to=None)
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Conv_1 (Conv3D)              (None, 94, 112, 94, 64)   1792
# _________________________________________________________________
# Pool_1 (MaxPooling3D)        (None, 31, 37, 31, 64)    0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 31, 37, 31, 64)    0
# _________________________________________________________________
# Conv_2 (Conv3D)              (None, 29, 35, 29, 64)    110656
# _________________________________________________________________
# Pool_2 (MaxPooling3D)        (None, 9, 11, 9, 64)      0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 9, 11, 9, 64)      0
# _________________________________________________________________
# Conv_3 (Conv3D)              (None, 7, 9, 7, 64)       110656
# _________________________________________________________________
# Conv_4 (Conv3D)              (None, 5, 7, 5, 64)       110656
# _________________________________________________________________
# Pool_4 (MaxPooling3D)        (None, 1, 2, 1, 64)       0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 1, 2, 1, 64)       0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 333,889
# Trainable params: 333,889
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Visualization

# %%
def visualize_weights(model):
    # Visualize weights
    W = model.layers[0].get_weights()[0]
    W = np.squeeze(W)[:,:,2]
    print("W shape : ", W.shape)

    print("Weights mean {}".format(W.mean()))
    plt.figure(figsize=(20, 5))
    plt.title('conv1 weights')
    plt.imshow(make_mosaic(W, 2, 2), cmap="gray")
    plt.show()

# %%
import numpy.ma as ma
def make_mosaic(imgs, nrows, ncols, border=1):
    """
    Given a set of images with all the same shape, makes a
    mosaic with nrows and ncols
    """
    nimgs = imgs.shape[0]
    imshape = imgs.shape[1:]
    
    mosaic = ma.masked_all((nrows * imshape[0] + (nrows - 1) * border,
                            ncols * imshape[1] + (ncols - 1) * border),
                            dtype=np.float32)
    
    paddedh = imshape[0] + border
    paddedw = imshape[1] + border
    for i in range(nimgs):
        row = int(np.floor(i / ncols))
        col = i % ncols
        
        mosaic[row * paddedh:row * paddedh + imshape[0],
               col * paddedw:col * paddedw + imshape[1]] = imgs[i]
    return mosaic

# %%
def reset_weights(model):
    session = K.get_session()
    for layer in model.layers: 
        if hasattr(layer, 'kernel_initializer'):
            layer.kernel.initializer.run(session=session)

# %%
# Visualize weights
print("Pre-trained model layer 1 weights:")
visualize_weights(model)
model_untrained = load_model(model_path)
reset_weights(model_untrained)
print("Random model layer 1 weights:")
visualize_weights(model_untrained)
# Out:
# Pre-trained model layer 1 weights:
# W shape :  (3, 3, 64)
# Weights mean -0.0010960017098113894
# Random model layer 1 weights:
# W shape :  (3, 3, 64)
# Weights mean -0.0022146941628307104

# %% [markdown]
# # Visualization

# %%
def plot_overlay(image, image_idx, X_holdout, lesion_masks_holdout, analysis):
    r = 2
    c = 2
    # Displaying the gradient
    plt.figure(figsize=(14,12))
    plt.subplots_adjust(hspace=0.15, wspace=0.)
    ax1 = plt.subplot(r, c, 1)
    plt.imshow(image[0,:,:,sl].squeeze(), cmap='gray', interpolation=None)
    plt.title("Scan")
    ax2 = plt.subplot(r, c, 2)
    plt.imshow(lesion_masks_holdout[image_idx,:,:,sl].squeeze(), cmap='gray', interpolation=None)
    plt.title("Lesion mask")
    ax3 = plt.subplot(r, c, 3)
    plt.imshow(image[0,:,:,sl].squeeze(), cmap='gray', interpolation=None)
    plt.imshow(lesion_masks_holdout[image_idx,:,:,sl].squeeze(), cmap='Reds', alpha=0.6, vmin=0.1)
    plt.title("Lesion mask over scan")
    ax4 = plt.subplot(r, c, 4)
    plt.imshow(image[0,:,:,sl].squeeze(), cmap='gray', interpolation=None)
    plt.imshow(analysis.squeeze()[:,:,sl], cmap='Reds', interpolation='nearest', alpha=0.6)
    plt.title("Heatmap overlayed")
    plt.show()

# %%
num_trials = 10
weights = ["weights-augm-trial%i-improvement-BEST.hdf5"%i for i in range(num_trials)]

# %%
import keras.layers
import keras.models
import keras.utils

import innvestigate.utils as iutils

# %%
model = load_model(model_path)
model_dir = os.path.join(result_dir, weights[6]) # select best model
#model_dir = os.path.join(result_dir, weights[1]) # select other model
model.load_weights(model_dir)

# %%
image_idx = 11
sl = 48
b = 1
test_loader = CISDataset(X_holdout, y_holdout, transform=[intensity], batch_size=b, shuffle=False, z_factor=z_factor, mask=mask)
image = test_loader[image_idx][0][[0]]
label = test_loader[image_idx][1][[0]]
# Out:
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()

# %%
print(label)
# Out:
# [1]

# %%
image.shape
# Out:
# (1, 96, 114, 96, 1)

# %%
pred = model.predict(image)
print("Model prediction: {} with final sigmoid output: {:.4f}".format((pred.item()>=0.5)*1, pred.item()))
# Out:
# Model prediction: 1 with final sigmoid output: 0.6073

# %%
# Creating an analyzer
gradient_analyzer = innvestigate.create_analyzer("gradient", model, postprocess="abs")

# Applying the analyzer
analysis = gradient_analyzer.analyze(image)

# Visualize
plot_overlay(image, image_idx, X_holdout, lesion_masks_holdout, analysis)

# %%
# Creating an analyzer
gradient_analyzer = innvestigate.create_analyzer("deconvnet", model)

# Applying the analyzer
analysis = gradient_analyzer.analyze(image)

# Visualize
plot_overlay(image, image_idx, X_holdout, lesion_masks_holdout, analysis)

# %%
# Creating an analyzer
gradient_analyzer = innvestigate.create_analyzer("guided_backprop", model)#, postprocess="abs")

# Applying the analyzer
analysis = gradient_analyzer.analyze(image)

# Visualize
plot_overlay(image, image_idx, X_holdout, lesion_masks_holdout, analysis)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-23c10d40b848> in <module>
#       3
#       4 # Applying the analyzer
# ----> 5 analysis = gradient_analyzer.analyze(image)
#       6
#       7 # Visualize
#
# ~/.local/lib/python3.6/site-packages/innvestigate/analyzer/base.py in analyze(self, X, neuron_selection)
#     490             ret = self._analyzer_model.predict_on_batch(X+[neuron_selection])
#     491         else:
# --> 492             ret = self._analyzer_model.predict_on_batch(X)
#     493
#     494         if self._n_debug_output > 0:
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training.py in predict_on_batch(self, x)
#    1270             ins = x
#    1271         self._make_predict_function()
# -> 1272         outputs = self.predict_function(ins)
#    1273         return unpack_singleton(outputs)
#    1274
#
# ~/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2664                 return self._legacy_call(inputs)
#    2665
# -> 2666             return self._call(inputs)
#    2667         else:
#    2668             if py_any(is_tensor(x) for x in inputs):
#
# ~/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2633                                 feed_symbols,
#    2634                                 symbol_vals,
# -> 2635                                 session)
#    2636         fetched = self._callable_fn(*array_vals)
#    2637         return fetched[:len(self.outputs)]
#
# ~/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _make_callable(self, feed_arrays, feed_symbols, symbol_vals, session)
#    2585         callable_opts.target.append(self.updates_op.name)
#    2586         # Create callable.
# -> 2587         callable_fn = session._make_callable_from_options(callable_opts)
#    2588         # Cache parameters corresponding to the generated callable, so that
#    2589         # we can detect future mismatches and refresh the callable.
#
# ~/anaconda2/envs/postal/lib/python3.6/site-packages/tensorflow/python/client/session.py in _make_callable_from_options(self, callable_options)
#    1428       A handle to the new callable.
#    1429     """
# -> 1430     self._extend_graph()
#    1431     return BaseSession._Callable(self, callable_options)
#    1432
#
# ~/anaconda2/envs/postal/lib/python3.6/site-packages/tensorflow/python/client/session.py in _extend_graph(self)
#    1310   def _extend_graph(self):
#    1311     with self._graph._session_run_lock():  # pylint: disable=protected-access
# -> 1312       tf_session.ExtendSession(self._session)
#    1313
#    1314   # The threshold to run garbage collection to delete dead tensors.
#
# KeyboardInterrupt:

# %%
# Creating an analyzer
gradient_analyzer = innvestigate.create_analyzer("input_t_gradient", model)#, postprocess="abs")

# Applying the analyzer
analysis = gradient_analyzer.analyze(image)

# Visualize
plot_overlay(image, image_idx, X_holdout, lesion_masks_holdout, analysis)

# %%
# Creating an analyzer
gradient_analyzer = innvestigate.create_analyzer("lrp.z", model)#, postprocess="abs")

# Applying the analyzer
analysis = gradient_analyzer.analyze(image)

# Visualize
plot_overlay(image, image_idx, X_holdout, lesion_masks_holdout, analysis)

# %%
# Creating an analyzer
gradient_analyzer = innvestigate.create_analyzer("lrp.epsilon", model, epsilon=1)

# Applying the analyzer
analysis = gradient_analyzer.analyze(image)

# Visualize
plot_overlay(image, image_idx, X_holdout, lesion_masks_holdout, analysis)

# %% [markdown]
# ## Using only the pre-trained model / no fine-tuning

# %%
# loading pre-trained model
model = load_model(model_path)

# %%
image = test_loader[image_idx][0][[0]]
label = test_loader[image_idx][1][[0]]

# %%
print(label)

# %%
pred = model.predict(image)
print("Model prediction: {} with final simgoid output: {:.4f}".format((pred.item()>=0.5)*1, pred.item()))

# %%
image.shape

# %%
# Creating an analyzer
gradient_analyzer = innvestigate.create_analyzer("gradient", model, postprocess="abs")

# Applying the analyzer
analysis = gradient_analyzer.analyze(image)

# Visualize
plot_overlay(image, image_idx, X_holdout, lesion_masks_holdout, analysis)

# %%
# Creating an analyzer
gradient_analyzer = innvestigate.create_analyzer("deconvnet", model)

# Applying the analyzer
analysis = gradient_analyzer.analyze(image)

# Visualize
plot_overlay(image, image_idx, X_holdout, lesion_masks_holdout, analysis)

# %%
# Creating an analyzer
gradient_analyzer = innvestigate.create_analyzer("guided_backprop", model)#, postprocess="abs")

# Applying the analyzer
analysis = gradient_analyzer.analyze(image)

# Visualize
plot_overlay(image, image_idx, X_holdout, lesion_masks_holdout, analysis)

# %%
# Creating an analyzer
gradient_analyzer = innvestigate.create_analyzer("input_t_gradient", model)#, postprocess="abs")

# Applying the analyzer
analysis = gradient_analyzer.analyze(image)

# Visualize
plot_overlay(image, image_idx, X_holdout, lesion_masks_holdout, analysis)

# %%
# Creating an analyzer
gradient_analyzer = innvestigate.create_analyzer("lrp.z", model)#, postprocess="abs")

# Applying the analyzer
analysis = gradient_analyzer.analyze(image)

# Visualize
plot_overlay(image, image_idx, X_holdout, lesion_masks_holdout, analysis)

# %%
# Creating an analyzer
gradient_analyzer = innvestigate.create_analyzer("lrp.epsilon", model, epsilon=1)

# Applying the analyzer
analysis = gradient_analyzer.analyze(image)

# Visualize
plot_overlay(image, image_idx, X_holdout, lesion_masks_holdout, analysis)

# %% [markdown]
# ## Random weights

# %%
# use random weights
model = load_model(model_path)
reset_weights(model)

# %%
image = test_loader[image_idx][0][[0]]
label = test_loader[image_idx][1][[0]]

# %%
print(label)

# %%
# Creating an analyzer
gradient_analyzer = innvestigate.create_analyzer("gradient", model, postprocess="abs")

# Applying the analyzer
analysis = gradient_analyzer.analyze(image)

# Visualize
plot_overlay(image, image_idx, X_holdout, lesion_masks_holdout, analysis)

# %%
# Creating an analyzer
gradient_analyzer = innvestigate.create_analyzer("deconvnet", model)

# Applying the analyzer
analysis = gradient_analyzer.analyze(image)

# Visualize
plot_overlay(image, image_idx, X_holdout, lesion_masks_holdout, analysis)

# %%
# Creating an analyzer
gradient_analyzer = innvestigate.create_analyzer("guided_backprop", model)#, postprocess="abs")

# Applying the analyzer
analysis = gradient_analyzer.analyze(image)

# Visualize
plot_overlay(image, image_idx, X_holdout, lesion_masks_holdout, analysis)

# %%
# Creating an analyzer
gradient_analyzer = innvestigate.create_analyzer("input_t_gradient", model)#, postprocess="abs")

# Applying the analyzer
analysis = gradient_analyzer.analyze(image)

# Visualize
plot_overlay(image, image_idx, X_holdout, lesion_masks_holdout, analysis)

# %%
# Creating an analyzer
gradient_analyzer = innvestigate.create_analyzer("lrp.z", model)#, postprocess="abs")

# Applying the analyzer
analysis = gradient_analyzer.analyze(image)

# Visualize
plot_overlay(image, image_idx, X_holdout, lesion_masks_holdout, analysis)

# %%
# Creating an analyzer
gradient_analyzer = innvestigate.create_analyzer("lrp.epsilon", model, epsilon=1)

# Applying the analyzer
analysis = gradient_analyzer.analyze(image)

# Visualize
plot_overlay(image, image_idx, X_holdout, lesion_masks_holdout, analysis)

# %%
quit()
