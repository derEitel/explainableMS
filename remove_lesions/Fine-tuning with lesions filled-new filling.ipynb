# %% [markdown]
# For fine-tuning we have 3 datasets: train, validation and holdout

# %%
import numpy as np
import pandas as pd
import nibabel as nib
import nilearn

from scipy import interp
from sklearn.utils import shuffle
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, auc
from sklearn.model_selection import KFold

import matplotlib.pyplot as plt
import os
import time
import h5py

# keras
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.models import load_model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils import Sequence
import keras.backend as K

from config import *
from utils import specificity, sensitivity, balanced_accuracy, IntensityRescale, sagittal_flip, translate
# Out:
# Using TensorFlow backend.

# %%
# Start timing
start_time = time.time()

# %%
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.gpu_options.visible_device_list = "7"
set_session(tf.Session(config=config))

# %%
zero_one_normalize = True
dtype = np.float32
result_dir = "/analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions"

# %%
# !mkdir -p $result_dir

# %%
# load hdf5 files and extract columns
train_h5 = h5py.File('/analysis/share/Ritter/MS/CIS/train_dataset_FLAIR_lesions_filled_inclWMmask.h5', 'r')
holdout_h5 = h5py.File('/analysis/share/Ritter/MS/CIS/holdout_dataset_FLAIR_lesions_filled_inclWMmask.h5', 'r')

X_train, y_train = train_h5['X'], train_h5['y']
X_holdout, y_holdout = holdout_h5['X'], holdout_h5['y']

# %%
# convert data to numpy arrays
X_train = np.array(X_train, dtype=dtype)
y_train = np.array(y_train)

X_holdout = np.array(X_holdout, dtype=dtype)
y_holdout = np.array(y_holdout)

# %%
print("Total training set length: {}".format(len(y_train)))
print("Number of healthy controls: {}".format(len(np.array(y_train)[np.array(y_train)==0.])))
print("Number of MS patients: {}".format(len(np.array(y_train)[np.array(y_train)==1.])))

print("Total holdout set length: {}".format(len(y_holdout)))
print("Number of healthy controls: {}".format(len(np.array(y_holdout)[np.array(y_holdout)==0.])))
print("Number of MS patients: {}".format(len(np.array(y_holdout)[np.array(y_holdout)==1.])))
# Out:
# Total training set length: 124
# Number of healthy controls: 61
# Number of MS patients: 63
# Total holdout set length: 23
# Number of healthy controls: 10
# Number of MS patients: 13

# %%
class CISDataset(Sequence):
    def __init__(self, X, y, transform=None, batch_size=4, z_factor=None, shuffle=True, mask=None):
        self.X = X
        self.y = y
        self.transform = transform
        self.batch_size = batch_size
        self.z_factor = z_factor
        self.shuffle = shuffle
        self.mask = mask
        
    def __len__(self):
        return int(np.ceil(len(self.y)/self.batch_size))
    
    def __getitem__(self, idx):
        # add BET
        image = np.expand_dims(self.X[idx * self.batch_size:(idx + 1) * self.batch_size],5)
        #label = np.array((batch_idx['label'] == "MS")* 1, dtype=np.int8) 
        label = np.array(self.y[idx * self.batch_size:(idx + 1) * self.batch_size], dtype=np.int8)
        
        if self.mask is not None:
            for i in range(image.shape[0]):
                image[i] *= self.mask
        
        for transformation in self.transform:
            image = transformation(image)
        
        return image, label
    
    def on_epoch_end(self):
        if self.shuffle:
            self.X, self.y = shuffle(self.X, self.y)

# %%
mask = None

# %%
intensity = IntensityRescale(masked=False)

# %%
if zero_one_normalize:
    cis_data = CISDataset(X_train, y_train, transform=[intensity], batch_size=4)
else:
    cis_data = CISDataset(X_train, y_train, batch_size=4)

# %%
plt.figure()
plt.title("Normalized between zero and 1")
plt.hist(cis_data[4][0][0].flatten())
plt.show()
# Out:
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()

# %%
plt.figure()
plt.title("Scan image")
plt.imshow(np.squeeze(cis_data[4][0][0])[:,:,42], cmap='gray')
plt.show()
# Out:
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()

# %%
# TODO compare with healthy brain
plt.figure()
plt.title("Scan image")
plt.imshow(np.squeeze(X_train[15])[:,:,48], cmap='gray')
plt.show()

# %% [markdown]
# # Model

# %%
def init_model(path, finetune=True, up_to=7):
    model = load_model(path)
    model.load_weights(path)
    if finetune:
        for layer in model.layers[:up_to]:
            layer.trainable = False
    return model

# %%
# load model weights
#model_path = "/analysis/share/Ritter/models/fabi/ADNI/pretraining_paper/model.h5"
model_path = "/analysis/share/Ritter/models/fabi/ADNI/pretraining_paper/model_trial_6.h5"
model = init_model(model_path, finetune=False, up_to=None)
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Conv_1 (Conv3D)              (None, 94, 112, 94, 64)   1792
# _________________________________________________________________
# Pool_1 (MaxPooling3D)        (None, 31, 37, 31, 64)    0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 31, 37, 31, 64)    0
# _________________________________________________________________
# Conv_2 (Conv3D)              (None, 29, 35, 29, 64)    110656
# _________________________________________________________________
# Pool_2 (MaxPooling3D)        (None, 9, 11, 9, 64)      0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 9, 11, 9, 64)      0
# _________________________________________________________________
# Conv_3 (Conv3D)              (None, 7, 9, 7, 64)       110656
# _________________________________________________________________
# Conv_4 (Conv3D)              (None, 5, 7, 5, 64)       110656
# _________________________________________________________________
# Pool_4 (MaxPooling3D)        (None, 1, 2, 1, 64)       0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 1, 2, 1, 64)       0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 333,889
# Trainable params: 333,889
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Visualization

# %%
def visualize_weights(model):
    # Visualize weights
    W = model.layers[0].get_weights()[0]
    W = np.squeeze(W)[:,:,2]
    print("W shape : ", W.shape)

    print("Weights mean {}".format(W.mean()))
    plt.figure(figsize=(20, 5))
    plt.title('conv1 weights')
    plt.imshow(make_mosaic(W, 2, 2), cmap="gray")
    plt.show()

# %%
import numpy.ma as ma
def make_mosaic(imgs, nrows, ncols, border=1):
    """
    Given a set of images with all the same shape, makes a
    mosaic with nrows and ncols
    """
    nimgs = imgs.shape[0]
    imshape = imgs.shape[1:]
    
    mosaic = ma.masked_all((nrows * imshape[0] + (nrows - 1) * border,
                            ncols * imshape[1] + (ncols - 1) * border),
                            dtype=np.float32)
    
    paddedh = imshape[0] + border
    paddedw = imshape[1] + border
    for i in range(nimgs):
        row = int(np.floor(i / ncols))
        col = i % ncols
        
        mosaic[row * paddedh:row * paddedh + imshape[0],
               col * paddedw:col * paddedw + imshape[1]] = imgs[i]
    return mosaic

# %%
def reset_weights(model):
    # Note this only used for visualization below
    session = K.get_session()
    for layer in model.layers: 
        if hasattr(layer, 'kernel_initializer'):
            layer.kernel.initializer.run(session=session)

# %%
# Visualize weights
print("Pre-trained model layer 1 weights:")
visualize_weights(model)
model_untrained = load_model(model_path)
reset_weights(model_untrained)
print("Random model layer 1 weights:")
visualize_weights(model_untrained)
# Out:
# Pre-trained model layer 1 weights:
# W shape :  (3, 3, 64)
# Weights mean -0.0010960017098113894
# Random model layer 1 weights:
# W shape :  (3, 3, 64)
# Weights mean 0.002811555750668049

# %% [markdown]
# ## Training

# %%
X_train.shape
# Out:
# (124, 96, 114, 96)

# %%
from sklearn.model_selection import train_test_split

# %%
# split training set
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.15, random_state=77)

# %%
# training args
lr = 0.0008
lr_decay = 0.002
transforms = [intensity, sagittal_flip, translate]

num_trials = 10
store_models = True

# callbacks
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1, mode='auto')

accuracies = []
balanced_accuracies = []
sensitivities = []
specificities = []
max_acc = []

for i in range(num_trials):
    print("Trial %i" %i)
    
    # init model
    model = init_model(model_path, finetune=False, up_to=None)    
    opti = Adam(lr=lr, decay=lr_decay)
    model.compile(optimizer=opti, loss='binary_crossentropy', metrics=['accuracy'])
    
    # callbacks
    earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=15, verbose=1, mode='auto')
    if store_models:
        result_path = os.path.join(result_dir, "weights-augm-trial%i-improvement-BEST.hdf5" %i)
        model_checkpoint = ModelCheckpoint(result_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max', save_weights_only=True)
        callbacks = [earlystop, model_checkpoint]
    else:
        callbacks = [earlystop]
        
    train_loader = CISDataset(X_train, y_train, transform=transforms, batch_size=b, shuffle=True)
    val_loader = CISDataset(X_val, y_val, transform=[intensity], batch_size=1, shuffle=False)
    
    # Start training
    history = model.fit_generator(train_loader,
                        epochs=num_epochs,
                        verbose=1,
                        validation_data=val_loader,
                        callbacks=callbacks)
    # Plot training curves
    plt.figure(figsize=(11, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history["loss"])
    plt.plot(history.history["val_loss"])
    plt.legend(["Train", "Val"])
    plt.title("Loss")
    plt.subplot(1, 2, 2)
    plt.plot(history.history["acc"])
    plt.plot(history.history["val_acc"])
    plt.legend(["Train", "Val"])
    plt.title("Accuracy")
    plt.show()
    # Evaluation
    y_pred = model.predict_generator(val_loader)
    #y_true = [item for sublist in [val_loader[batch_idx][1] for batch_idx in range(len(val_loader))] for item in sublist]
    bal_acc = balanced_accuracy(y_val, y_pred>0.5)
    sens = sensitivity(y_val, y_pred>0.5)
    spec = specificity(y_val, y_pred>0.5)
    # Store results
    accuracies.append(history.history["val_acc"][-1])
    balanced_accuracies.append(bal_acc)
    max_acc.append(np.max(history.history["val_acc"]))
    sensitivities.append(sens)
    specificities.append(spec)

training_time = time.time() - start_time
print("Training Time: {}h:{}m:{}s".format(
            training_time//3600, (training_time//60)%60, training_time%60))

print("Validation final accuracies: \n {}".format(accuracies))
print("Validation final accuracies mean: {}".format(np.mean(accuracies)))
print("Validation best accuracies: \n {}".format(max_acc))
print("Validation best accuracies mean: {}".format(np.mean(max_acc)))
print("Validation balanced accuracies: \n {}".format(balanced_accuracies))
print("Validation balanced accuracies mean: {}".format(np.mean(balanced_accuracies)))
print("Validation final sensitivities: \n {}".format(sensitivities))
print("Validation final sensitivities' mean: {}".format(np.mean(sensitivities)))
print("Validation final specificities: \n {}".format(specificities))
print("Validation final specificities' mean: {}".format(np.mean(specificities)))
# Out:
# Trial 0
# Epoch 1/200
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()
# 27/27 [==============================] - 8s 285ms/step - loss: 1.0363 - acc: 0.4356 - val_loss: 0.8921 - val_acc: 0.6842
#
# Epoch 00001: val_acc improved from -inf to 0.68421, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial0-improvement-BEST.hdf5
# Epoch 2/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.8899 - acc: 0.5736 - val_loss: 0.9956 - val_acc: 0.3158
#
# Epoch 00002: val_acc did not improve from 0.68421
# Epoch 3/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.9265 - acc: 0.5180 - val_loss: 0.8076 - val_acc: 0.6316
#
# Epoch 00003: val_acc did not improve from 0.68421
# Epoch 4/200
# 27/27 [==============================] - 4s 154ms/step - loss: 0.9877 - acc: 0.5458 - val_loss: 0.8561 - val_acc: 0.4737
#
# Epoch 00004: val_acc did not improve from 0.68421
# Epoch 5/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.8956 - acc: 0.5088 - val_loss: 0.9052 - val_acc: 0.3158
#
# Epoch 00005: val_acc did not improve from 0.68421
# Epoch 6/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.8540 - acc: 0.5190 - val_loss: 0.8665 - val_acc: 0.3158
#
# Epoch 00006: val_acc did not improve from 0.68421
# Epoch 7/200
# 27/27 [==============================] - 5s 173ms/step - loss: 0.9207 - acc: 0.4820 - val_loss: 0.8440 - val_acc: 0.4211
#
# Epoch 00007: val_acc did not improve from 0.68421
# Epoch 8/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.8520 - acc: 0.4912 - val_loss: 0.8718 - val_acc: 0.3158
#
# Epoch 00008: val_acc did not improve from 0.68421
# Epoch 9/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.7897 - acc: 0.5644 - val_loss: 0.8034 - val_acc: 0.3684
#
# Epoch 00009: val_acc did not improve from 0.68421
# Epoch 10/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.7731 - acc: 0.5747 - val_loss: 0.7234 - val_acc: 0.6842
#
# Epoch 00010: val_acc did not improve from 0.68421
# Epoch 11/200
# 27/27 [==============================] - 4s 155ms/step - loss: 0.7937 - acc: 0.5561 - val_loss: 0.7765 - val_acc: 0.5789
#
# Epoch 00011: val_acc did not improve from 0.68421
# Epoch 12/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.7613 - acc: 0.5839 - val_loss: 0.7241 - val_acc: 0.7895
#
# Epoch 00012: val_acc improved from 0.68421 to 0.78947, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial0-improvement-BEST.hdf5
# Epoch 13/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.7488 - acc: 0.5922 - val_loss: 0.7284 - val_acc: 0.7368
#
# Epoch 00013: val_acc did not improve from 0.78947
# Epoch 14/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.7188 - acc: 0.6571 - val_loss: 0.6723 - val_acc: 0.7895
#
# Epoch 00014: val_acc did not improve from 0.78947
# Epoch 15/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.7394 - acc: 0.6200 - val_loss: 0.7423 - val_acc: 0.6842
#
# Epoch 00015: val_acc did not improve from 0.78947
# Epoch 16/200
# 27/27 [==============================] - 5s 173ms/step - loss: 0.6939 - acc: 0.7034 - val_loss: 0.6740 - val_acc: 0.7368
#
# Epoch 00016: val_acc did not improve from 0.78947
# Epoch 17/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.6772 - acc: 0.7034 - val_loss: 0.6392 - val_acc: 0.7368
#
# Epoch 00017: val_acc did not improve from 0.78947
# Epoch 18/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.6526 - acc: 0.7415 - val_loss: 0.6152 - val_acc: 0.8421
#
# Epoch 00018: val_acc improved from 0.78947 to 0.84211, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial0-improvement-BEST.hdf5
# Epoch 19/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.5870 - acc: 0.7961 - val_loss: 0.5709 - val_acc: 0.8421
#
# Epoch 00019: val_acc did not improve from 0.84211
# Epoch 20/200
# 27/27 [==============================] - 4s 155ms/step - loss: 0.6005 - acc: 0.7683 - val_loss: 0.6488 - val_acc: 0.7895
#
# Epoch 00020: val_acc did not improve from 0.84211
# Epoch 21/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.5992 - acc: 0.7127 - val_loss: 0.8822 - val_acc: 0.4737
#
# Epoch 00021: val_acc did not improve from 0.84211
# Epoch 22/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.5945 - acc: 0.7961 - val_loss: 0.5845 - val_acc: 0.8947
#
# Epoch 00022: val_acc improved from 0.84211 to 0.89474, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial0-improvement-BEST.hdf5
# Epoch 23/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.5389 - acc: 0.8517 - val_loss: 0.5230 - val_acc: 0.8947
#
# Epoch 00023: val_acc did not improve from 0.89474
# Epoch 24/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.5129 - acc: 0.8424 - val_loss: 0.7256 - val_acc: 0.5789
#
# Epoch 00024: val_acc did not improve from 0.89474
# Epoch 25/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.4750 - acc: 0.8610 - val_loss: 0.4856 - val_acc: 0.8947
#
# Epoch 00025: val_acc did not improve from 0.89474
# Epoch 26/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.5274 - acc: 0.8424 - val_loss: 0.4986 - val_acc: 0.8421
#
# Epoch 00026: val_acc did not improve from 0.89474
# Epoch 27/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.5666 - acc: 0.8146 - val_loss: 0.5789 - val_acc: 0.7368
#
# Epoch 00027: val_acc did not improve from 0.89474
# Epoch 28/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.5191 - acc: 0.7971 - val_loss: 0.5678 - val_acc: 0.8947
#
# Epoch 00028: val_acc did not improve from 0.89474
# Epoch 29/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.4949 - acc: 0.8517 - val_loss: 0.6419 - val_acc: 0.6316
#
# Epoch 00029: val_acc did not improve from 0.89474
# Epoch 30/200
# 27/27 [==============================] - 5s 177ms/step - loss: 0.4521 - acc: 0.8888 - val_loss: 0.6576 - val_acc: 0.6316
#
# Epoch 00030: val_acc did not improve from 0.89474
# Epoch 31/200
# 27/27 [==============================] - 4s 155ms/step - loss: 0.3906 - acc: 0.9073 - val_loss: 0.5541 - val_acc: 0.8421
#
# Epoch 00031: val_acc did not improve from 0.89474
# Epoch 32/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.4574 - acc: 0.8610 - val_loss: 0.5930 - val_acc: 0.7895
#
# Epoch 00032: val_acc did not improve from 0.89474
# Epoch 33/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.4307 - acc: 0.8610 - val_loss: 0.5336 - val_acc: 0.7895
#
# Epoch 00033: val_acc did not improve from 0.89474
# Epoch 34/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.4469 - acc: 0.8795 - val_loss: 0.5174 - val_acc: 0.8947
#
# Epoch 00034: val_acc did not improve from 0.89474
# Epoch 35/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.3845 - acc: 0.9166 - val_loss: 0.5851 - val_acc: 0.7368
#
# Epoch 00035: val_acc did not improve from 0.89474
# Epoch 36/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.4026 - acc: 0.9073 - val_loss: 0.5195 - val_acc: 0.8947
#
# Epoch 00036: val_acc did not improve from 0.89474
# Epoch 37/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.3661 - acc: 0.9073 - val_loss: 0.5556 - val_acc: 0.7895
#
# Epoch 00037: val_acc did not improve from 0.89474
# Epoch 38/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.3614 - acc: 0.9444 - val_loss: 0.5210 - val_acc: 0.8947
#
# Epoch 00038: val_acc did not improve from 0.89474
# Epoch 39/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.3457 - acc: 0.9166 - val_loss: 0.5913 - val_acc: 0.7895
#
# Epoch 00039: val_acc did not improve from 0.89474
# Epoch 40/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.3555 - acc: 0.9166 - val_loss: 0.5614 - val_acc: 0.8421
#
# Epoch 00040: val_acc did not improve from 0.89474
# Epoch 00040: early stopping
# Trial 1
# Epoch 1/200
# 27/27 [==============================] - 5s 203ms/step - loss: 0.9865 - acc: 0.5829 - val_loss: 0.8629 - val_acc: 0.6842
#
# Epoch 00001: val_acc improved from -inf to 0.68421, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial1-improvement-BEST.hdf5
# Epoch 2/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.9644 - acc: 0.5180 - val_loss: 0.8764 - val_acc: 0.5263
#
# Epoch 00002: val_acc did not improve from 0.68421
# Epoch 3/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.9341 - acc: 0.4717 - val_loss: 0.9817 - val_acc: 0.3158
#
# Epoch 00003: val_acc did not improve from 0.68421
# Epoch 4/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.9021 - acc: 0.5273 - val_loss: 0.9387 - val_acc: 0.3158
#
# Epoch 00004: val_acc did not improve from 0.68421
# Epoch 5/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.8599 - acc: 0.4727 - val_loss: 0.9187 - val_acc: 0.3158
#
# Epoch 00005: val_acc did not improve from 0.68421
# Epoch 6/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.8847 - acc: 0.4542 - val_loss: 0.8695 - val_acc: 0.3158
#
# Epoch 00006: val_acc did not improve from 0.68421
# Epoch 7/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.8449 - acc: 0.5551 - val_loss: 0.8825 - val_acc: 0.3158
#
# Epoch 00007: val_acc did not improve from 0.68421
# Epoch 8/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.8236 - acc: 0.5644 - val_loss: 0.9322 - val_acc: 0.3158
#
# Epoch 00008: val_acc did not improve from 0.68421
# Epoch 9/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.8509 - acc: 0.4995 - val_loss: 0.8356 - val_acc: 0.3158
#
# Epoch 00009: val_acc did not improve from 0.68421
# Epoch 10/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.8176 - acc: 0.4912 - val_loss: 0.8185 - val_acc: 0.3158
#
# Epoch 00010: val_acc did not improve from 0.68421
# Epoch 11/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.7851 - acc: 0.5736 - val_loss: 0.7685 - val_acc: 0.5263
#
# Epoch 00011: val_acc did not improve from 0.68421
# Epoch 12/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.7961 - acc: 0.5654 - val_loss: 0.8518 - val_acc: 0.3158
#
# Epoch 00012: val_acc did not improve from 0.68421
# Epoch 13/200
# 27/27 [==============================] - 5s 174ms/step - loss: 0.7610 - acc: 0.5747 - val_loss: 0.8656 - val_acc: 0.3158
#
# Epoch 00013: val_acc did not improve from 0.68421
# Epoch 14/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.7543 - acc: 0.5829 - val_loss: 0.7315 - val_acc: 0.7368
#
# Epoch 00014: val_acc improved from 0.68421 to 0.73684, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial1-improvement-BEST.hdf5
# Epoch 15/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.7344 - acc: 0.6200 - val_loss: 0.7981 - val_acc: 0.3158
#
# Epoch 00015: val_acc did not improve from 0.73684
# Epoch 16/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.6934 - acc: 0.6849 - val_loss: 0.7648 - val_acc: 0.4737
#
# Epoch 00016: val_acc did not improve from 0.73684
# Epoch 17/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.7211 - acc: 0.6107 - val_loss: 0.7350 - val_acc: 0.6842
#
# Epoch 00017: val_acc did not improve from 0.73684
# Epoch 18/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.7069 - acc: 0.6478 - val_loss: 0.7469 - val_acc: 0.5789
#
# Epoch 00018: val_acc did not improve from 0.73684
# Epoch 19/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.6852 - acc: 0.6756 - val_loss: 0.7373 - val_acc: 0.5789
#
# Epoch 00019: val_acc did not improve from 0.73684
# Epoch 20/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.6680 - acc: 0.6756 - val_loss: 0.7150 - val_acc: 0.6842
#
# Epoch 00020: val_acc did not improve from 0.73684
# Epoch 21/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.6531 - acc: 0.7219 - val_loss: 0.6710 - val_acc: 0.7368
#
# Epoch 00021: val_acc did not improve from 0.73684
# Epoch 22/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.6028 - acc: 0.7693 - val_loss: 0.5717 - val_acc: 0.8947
#
# Epoch 00022: val_acc improved from 0.73684 to 0.89474, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial1-improvement-BEST.hdf5
# Epoch 23/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.5855 - acc: 0.7683 - val_loss: 0.7702 - val_acc: 0.5263
#
# Epoch 00023: val_acc did not improve from 0.89474
# Epoch 24/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.5319 - acc: 0.8610 - val_loss: 0.6268 - val_acc: 0.6842
#
# Epoch 00024: val_acc did not improve from 0.89474
# Epoch 25/200
# 27/27 [==============================] - 5s 170ms/step - loss: 0.5050 - acc: 0.8239 - val_loss: 0.6960 - val_acc: 0.7368
#
# Epoch 00025: val_acc did not improve from 0.89474
# Epoch 26/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.5304 - acc: 0.8239 - val_loss: 0.5679 - val_acc: 0.6842
#
# Epoch 00026: val_acc did not improve from 0.89474
# Epoch 27/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.5393 - acc: 0.8239 - val_loss: 0.9436 - val_acc: 0.5263
#
# Epoch 00027: val_acc did not improve from 0.89474
# Epoch 28/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.5828 - acc: 0.7776 - val_loss: 0.6964 - val_acc: 0.6316
#
# Epoch 00028: val_acc did not improve from 0.89474
# Epoch 29/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.5941 - acc: 0.7971 - val_loss: 0.5320 - val_acc: 0.8421
#
# Epoch 00029: val_acc did not improve from 0.89474
# Epoch 30/200
# 27/27 [==============================] - 6s 231ms/step - loss: 0.4604 - acc: 0.8610 - val_loss: 0.6361 - val_acc: 0.7368
#
# Epoch 00030: val_acc did not improve from 0.89474
# Epoch 31/200
# 27/27 [==============================] - 6s 230ms/step - loss: 0.5261 - acc: 0.7971 - val_loss: 0.5580 - val_acc: 0.8421
#
# Epoch 00031: val_acc did not improve from 0.89474
# Epoch 32/200
# 27/27 [==============================] - 9s 346ms/step - loss: 0.4809 - acc: 0.8517 - val_loss: 0.5621 - val_acc: 0.8421
#
# Epoch 00032: val_acc did not improve from 0.89474
# Epoch 33/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.4595 - acc: 0.8702 - val_loss: 0.7019 - val_acc: 0.7368
#
# Epoch 00033: val_acc did not improve from 0.89474
# Epoch 34/200
# 27/27 [==============================] - 4s 154ms/step - loss: 0.4481 - acc: 0.8795 - val_loss: 0.6658 - val_acc: 0.7368
#
# Epoch 00034: val_acc did not improve from 0.89474
# Epoch 35/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.4126 - acc: 0.8888 - val_loss: 0.5067 - val_acc: 0.8421
#
# Epoch 00035: val_acc did not improve from 0.89474
# Epoch 36/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.4167 - acc: 0.9073 - val_loss: 0.6197 - val_acc: 0.7895
#
# Epoch 00036: val_acc did not improve from 0.89474
# Epoch 37/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.4272 - acc: 0.8980 - val_loss: 0.5163 - val_acc: 0.8421
#
# Epoch 00037: val_acc did not improve from 0.89474
# Epoch 38/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.4262 - acc: 0.8702 - val_loss: 0.5421 - val_acc: 0.7895
#
# Epoch 00038: val_acc did not improve from 0.89474
# Epoch 39/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.3968 - acc: 0.9166 - val_loss: 0.5582 - val_acc: 0.7895
#
# Epoch 00039: val_acc did not improve from 0.89474
# Epoch 40/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.3433 - acc: 0.9259 - val_loss: 0.6695 - val_acc: 0.7895
#
# Epoch 00040: val_acc did not improve from 0.89474
# Epoch 41/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.4421 - acc: 0.8888 - val_loss: 0.5330 - val_acc: 0.7895
#
# Epoch 00041: val_acc did not improve from 0.89474
# Epoch 42/200
# 27/27 [==============================] - 5s 183ms/step - loss: 0.3794 - acc: 0.9166 - val_loss: 0.5327 - val_acc: 0.8421
#
# Epoch 00042: val_acc did not improve from 0.89474
# Epoch 43/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.3909 - acc: 0.9259 - val_loss: 0.5860 - val_acc: 0.7895
#
# Epoch 00043: val_acc did not improve from 0.89474
# Epoch 44/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.3749 - acc: 0.9166 - val_loss: 0.5425 - val_acc: 0.8421
#
# Epoch 00044: val_acc did not improve from 0.89474
# Epoch 45/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.3102 - acc: 0.9444 - val_loss: 0.5256 - val_acc: 0.8947
#
# Epoch 00045: val_acc did not improve from 0.89474
# Epoch 46/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.3683 - acc: 0.9073 - val_loss: 0.5598 - val_acc: 0.7895
#
# Epoch 00046: val_acc did not improve from 0.89474
# Epoch 47/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.3857 - acc: 0.8980 - val_loss: 0.5125 - val_acc: 0.8947
#
# Epoch 00047: val_acc did not improve from 0.89474
# Epoch 48/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.3360 - acc: 0.9166 - val_loss: 0.7293 - val_acc: 0.6842
#
# Epoch 00048: val_acc did not improve from 0.89474
# Epoch 49/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.3356 - acc: 0.9351 - val_loss: 0.5350 - val_acc: 0.8421
#
# Epoch 00049: val_acc did not improve from 0.89474
# Epoch 50/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.3847 - acc: 0.8888 - val_loss: 0.5177 - val_acc: 0.8947
#
# Epoch 00050: val_acc did not improve from 0.89474
# Epoch 00050: early stopping
# Trial 2
# Epoch 1/200
# 27/27 [==============================] - 5s 198ms/step - loss: 1.0703 - acc: 0.4542 - val_loss: 1.1003 - val_acc: 0.3158
#
# Epoch 00001: val_acc improved from -inf to 0.31579, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial2-improvement-BEST.hdf5
# Epoch 2/200
# 27/27 [==============================] - 4s 155ms/step - loss: 0.9996 - acc: 0.4449 - val_loss: 0.8272 - val_acc: 0.6842
#
# Epoch 00002: val_acc improved from 0.31579 to 0.68421, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial2-improvement-BEST.hdf5
# Epoch 3/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.9831 - acc: 0.4449 - val_loss: 0.9741 - val_acc: 0.3158
#
# Epoch 00003: val_acc did not improve from 0.68421
# Epoch 4/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.9164 - acc: 0.4820 - val_loss: 0.9328 - val_acc: 0.3158
#
# Epoch 00004: val_acc did not improve from 0.68421
# Epoch 5/200
# 27/27 [==============================] - 4s 155ms/step - loss: 0.9448 - acc: 0.4356 - val_loss: 0.8652 - val_acc: 0.3158
#
# Epoch 00005: val_acc did not improve from 0.68421
# Epoch 6/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.9472 - acc: 0.4727 - val_loss: 0.8775 - val_acc: 0.3158
#
# Epoch 00006: val_acc did not improve from 0.68421
# Epoch 7/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.9027 - acc: 0.4717 - val_loss: 0.8469 - val_acc: 0.3158
#
# Epoch 00007: val_acc did not improve from 0.68421
# Epoch 8/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.8626 - acc: 0.4810 - val_loss: 0.8668 - val_acc: 0.3158
#
# Epoch 00008: val_acc did not improve from 0.68421
# Epoch 9/200
# 27/27 [==============================] - 6s 210ms/step - loss: 0.8432 - acc: 0.4912 - val_loss: 0.8095 - val_acc: 0.3158
#
# Epoch 00009: val_acc did not improve from 0.68421
# Epoch 10/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.8212 - acc: 0.4634 - val_loss: 0.8241 - val_acc: 0.3158
#
# Epoch 00010: val_acc did not improve from 0.68421
# Epoch 11/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.8052 - acc: 0.5458 - val_loss: 0.7331 - val_acc: 0.7368
#
# Epoch 00011: val_acc improved from 0.68421 to 0.73684, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial2-improvement-BEST.hdf5
# Epoch 12/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.7916 - acc: 0.4727 - val_loss: 0.7715 - val_acc: 0.4737
#
# Epoch 00012: val_acc did not improve from 0.73684
# Epoch 13/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.7586 - acc: 0.5458 - val_loss: 0.7957 - val_acc: 0.3158
#
# Epoch 00013: val_acc did not improve from 0.73684
# Epoch 14/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.7738 - acc: 0.5829 - val_loss: 0.7950 - val_acc: 0.3158
#
# Epoch 00014: val_acc did not improve from 0.73684
# Epoch 15/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.7490 - acc: 0.5551 - val_loss: 0.7718 - val_acc: 0.4737
#
# Epoch 00015: val_acc did not improve from 0.73684
# Epoch 16/200
# 27/27 [==============================] - 7s 275ms/step - loss: 0.7343 - acc: 0.6385 - val_loss: 0.6944 - val_acc: 0.7368
#
# Epoch 00016: val_acc did not improve from 0.73684
# Epoch 17/200
# 27/27 [==============================] - 5s 192ms/step - loss: 0.7450 - acc: 0.5736 - val_loss: 0.7501 - val_acc: 0.4737
#
# Epoch 00017: val_acc did not improve from 0.73684
# Epoch 18/200
# 27/27 [==============================] - 13s 465ms/step - loss: 0.7274 - acc: 0.5747 - val_loss: 0.7056 - val_acc: 0.7368
#
# Epoch 00018: val_acc did not improve from 0.73684
# Epoch 19/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.7064 - acc: 0.6571 - val_loss: 0.8058 - val_acc: 0.3158
#
# Epoch 00019: val_acc did not improve from 0.73684
# Epoch 20/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.7305 - acc: 0.5283 - val_loss: 0.6996 - val_acc: 0.7368
#
# Epoch 00020: val_acc did not improve from 0.73684
# Epoch 21/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.7019 - acc: 0.5839 - val_loss: 0.7025 - val_acc: 0.7368
#
# Epoch 00021: val_acc did not improve from 0.73684
# Epoch 22/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.6814 - acc: 0.6488 - val_loss: 0.6664 - val_acc: 0.6842
#
# Epoch 00022: val_acc did not improve from 0.73684
# Epoch 23/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.6588 - acc: 0.7127 - val_loss: 0.7728 - val_acc: 0.4737
#
# Epoch 00023: val_acc did not improve from 0.73684
# Epoch 24/200
# 27/27 [==============================] - 5s 187ms/step - loss: 0.6577 - acc: 0.6673 - val_loss: 0.5991 - val_acc: 0.8421
#
# Epoch 00024: val_acc improved from 0.73684 to 0.84211, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial2-improvement-BEST.hdf5
# Epoch 25/200
# 27/27 [==============================] - 4s 155ms/step - loss: 0.6176 - acc: 0.7590 - val_loss: 0.6109 - val_acc: 0.7895
#
# Epoch 00025: val_acc did not improve from 0.84211
# Epoch 26/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.6091 - acc: 0.7590 - val_loss: 0.7459 - val_acc: 0.5263
#
# Epoch 00026: val_acc did not improve from 0.84211
# Epoch 27/200
# 27/27 [==============================] - 4s 153ms/step - loss: 0.5802 - acc: 0.7693 - val_loss: 0.5762 - val_acc: 0.8947
#
# Epoch 00027: val_acc improved from 0.84211 to 0.89474, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial2-improvement-BEST.hdf5
# Epoch 28/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.5931 - acc: 0.7590 - val_loss: 0.5469 - val_acc: 0.8421
#
# Epoch 00028: val_acc did not improve from 0.89474
# Epoch 29/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.5458 - acc: 0.8146 - val_loss: 0.6564 - val_acc: 0.6842
#
# Epoch 00029: val_acc did not improve from 0.89474
# Epoch 30/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.4926 - acc: 0.8424 - val_loss: 0.6211 - val_acc: 0.6842
#
# Epoch 00030: val_acc did not improve from 0.89474
# Epoch 31/200
# 27/27 [==============================] - 5s 187ms/step - loss: 0.4915 - acc: 0.8332 - val_loss: 0.5127 - val_acc: 0.9474
#
# Epoch 00031: val_acc improved from 0.89474 to 0.94737, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial2-improvement-BEST.hdf5
# Epoch 32/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.4949 - acc: 0.8517 - val_loss: 0.5372 - val_acc: 0.8421
#
# Epoch 00032: val_acc did not improve from 0.94737
# Epoch 33/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.5018 - acc: 0.8517 - val_loss: 0.5872 - val_acc: 0.7895
#
# Epoch 00033: val_acc did not improve from 0.94737
# Epoch 34/200
# 27/27 [==============================] - 4s 155ms/step - loss: 0.4749 - acc: 0.8435 - val_loss: 0.5035 - val_acc: 0.8421
#
# Epoch 00034: val_acc did not improve from 0.94737
# Epoch 35/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.4746 - acc: 0.8610 - val_loss: 0.5600 - val_acc: 0.7368
#
# Epoch 00035: val_acc did not improve from 0.94737
# Epoch 36/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.4454 - acc: 0.8610 - val_loss: 0.5428 - val_acc: 0.8421
#
# Epoch 00036: val_acc did not improve from 0.94737
# Epoch 37/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.4149 - acc: 0.9073 - val_loss: 0.5894 - val_acc: 0.7895
#
# Epoch 00037: val_acc did not improve from 0.94737
# Epoch 38/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.4337 - acc: 0.8888 - val_loss: 0.5769 - val_acc: 0.7895
#
# Epoch 00038: val_acc did not improve from 0.94737
# Epoch 39/200
# 27/27 [==============================] - 6s 216ms/step - loss: 0.4146 - acc: 0.8702 - val_loss: 0.5547 - val_acc: 0.8421
#
# Epoch 00039: val_acc did not improve from 0.94737
# Epoch 40/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.3658 - acc: 0.9259 - val_loss: 0.5506 - val_acc: 0.8421
# Epoch 00040: val_acc did not improve from 0.94737
# Epoch 41/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.4030 - acc: 0.9073 - val_loss: 0.5442 - val_acc: 0.8947
#
# Epoch 00041: val_acc did not improve from 0.94737
# Epoch 42/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.3679 - acc: 0.9259 - val_loss: 0.5706 - val_acc: 0.8421
#
# Epoch 00042: val_acc did not improve from 0.94737
# Epoch 43/200
# 27/27 [==============================] - 4s 155ms/step - loss: 0.3876 - acc: 0.8702 - val_loss: 0.6084 - val_acc: 0.6842
#
# Epoch 00043: val_acc did not improve from 0.94737
# Epoch 44/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.3723 - acc: 0.8980 - val_loss: 0.5102 - val_acc: 0.8947
#
# Epoch 00044: val_acc did not improve from 0.94737
# Epoch 45/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.3595 - acc: 0.8980 - val_loss: 0.5703 - val_acc: 0.7895
#
# Epoch 00045: val_acc did not improve from 0.94737
# Epoch 46/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.3829 - acc: 0.9073 - val_loss: 0.5627 - val_acc: 0.7895
#
# Epoch 00046: val_acc did not improve from 0.94737
# Epoch 47/200
# 27/27 [==============================] - 4s 154ms/step - loss: 0.3847 - acc: 0.8888 - val_loss: 0.5910 - val_acc: 0.8421
#
# Epoch 00047: val_acc did not improve from 0.94737
# Epoch 48/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.3912 - acc: 0.9259 - val_loss: 0.5526 - val_acc: 0.7895
#
# Epoch 00048: val_acc did not improve from 0.94737
# Epoch 49/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.3477 - acc: 0.9259 - val_loss: 0.5931 - val_acc: 0.7368
#
# Epoch 00049: val_acc did not improve from 0.94737
# Epoch 00049: early stopping
# Trial 3
# Epoch 1/200
# 27/27 [==============================] - 6s 207ms/step - loss: 1.0310 - acc: 0.5088 - val_loss: 0.9299 - val_acc: 0.3158
#
# Epoch 00001: val_acc improved from -inf to 0.31579, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial3-improvement-BEST.hdf5
# Epoch 2/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.9617 - acc: 0.5458 - val_loss: 0.8494 - val_acc: 0.7368
#
# Epoch 00002: val_acc improved from 0.31579 to 0.73684, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial3-improvement-BEST.hdf5
# Epoch 3/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.8851 - acc: 0.5273 - val_loss: 1.0777 - val_acc: 0.3158
#
# Epoch 00003: val_acc did not improve from 0.73684
# Epoch 4/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.9393 - acc: 0.5551 - val_loss: 0.8173 - val_acc: 0.6842
#
# Epoch 00004: val_acc did not improve from 0.73684
# Epoch 5/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.8974 - acc: 0.5098 - val_loss: 0.7863 - val_acc: 0.6842
#
# Epoch 00005: val_acc did not improve from 0.73684
# Epoch 6/200
# 27/27 [==============================] - 5s 169ms/step - loss: 0.8292 - acc: 0.5376 - val_loss: 0.9547 - val_acc: 0.3158
#
# Epoch 00006: val_acc did not improve from 0.73684
# Epoch 7/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.8416 - acc: 0.4912 - val_loss: 0.7271 - val_acc: 0.7368
#
# Epoch 00007: val_acc did not improve from 0.73684
# Epoch 8/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.8229 - acc: 0.4717 - val_loss: 0.7987 - val_acc: 0.4211
#
# Epoch 00008: val_acc did not improve from 0.73684
# Epoch 9/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.8151 - acc: 0.4820 - val_loss: 0.8454 - val_acc: 0.3158
#
# Epoch 00009: val_acc did not improve from 0.73684
# Epoch 10/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.7827 - acc: 0.5098 - val_loss: 0.8088 - val_acc: 0.3158
#
# Epoch 00010: val_acc did not improve from 0.73684
# Epoch 11/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.7762 - acc: 0.5654 - val_loss: 0.8138 - val_acc: 0.3158
#
# Epoch 00011: val_acc did not improve from 0.73684
# Epoch 12/200
# 27/27 [==============================] - 5s 169ms/step - loss: 0.7562 - acc: 0.5654 - val_loss: 0.8539 - val_acc: 0.3158
#
# Epoch 00012: val_acc did not improve from 0.73684
# Epoch 13/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.7501 - acc: 0.5829 - val_loss: 0.7528 - val_acc: 0.6316
#
# Epoch 00013: val_acc did not improve from 0.73684
# Epoch 14/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.7123 - acc: 0.6849 - val_loss: 0.7435 - val_acc: 0.6842
#
# Epoch 00014: val_acc did not improve from 0.73684
# Epoch 15/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.6843 - acc: 0.6663 - val_loss: 0.8231 - val_acc: 0.3684
#
# Epoch 00015: val_acc did not improve from 0.73684
# Epoch 16/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.7199 - acc: 0.6025 - val_loss: 0.7455 - val_acc: 0.6316
#
# Epoch 00016: val_acc did not improve from 0.73684
# Epoch 17/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.6836 - acc: 0.6756 - val_loss: 0.6441 - val_acc: 0.7895
#
# Epoch 00017: val_acc improved from 0.73684 to 0.78947, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial3-improvement-BEST.hdf5
# Epoch 18/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.6762 - acc: 0.6952 - val_loss: 0.6558 - val_acc: 0.7368
#
# Epoch 00018: val_acc did not improve from 0.78947
# Epoch 19/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.6670 - acc: 0.7219 - val_loss: 0.7706 - val_acc: 0.5263
#
# Epoch 00019: val_acc did not improve from 0.78947
# Epoch 20/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.6405 - acc: 0.7127 - val_loss: 0.7338 - val_acc: 0.6842
#
# Epoch 00020: val_acc did not improve from 0.78947
# Epoch 21/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.5598 - acc: 0.8342 - val_loss: 0.7608 - val_acc: 0.5789
#
# Epoch 00021: val_acc did not improve from 0.78947
# Epoch 22/200
# 27/27 [==============================] - 5s 172ms/step - loss: 0.5828 - acc: 0.7961 - val_loss: 0.5756 - val_acc: 0.7895
#
# Epoch 00022: val_acc did not improve from 0.78947
# Epoch 23/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.5022 - acc: 0.8332 - val_loss: 0.7377 - val_acc: 0.6316
#
# Epoch 00023: val_acc did not improve from 0.78947
# Epoch 24/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.5449 - acc: 0.8239 - val_loss: 0.6486 - val_acc: 0.7368
#
# Epoch 00024: val_acc did not improve from 0.78947
# Epoch 25/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.5199 - acc: 0.8424 - val_loss: 0.6839 - val_acc: 0.6842
#
# Epoch 00025: val_acc did not improve from 0.78947
# Epoch 26/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.5493 - acc: 0.8239 - val_loss: 0.6723 - val_acc: 0.6842
#
# Epoch 00026: val_acc did not improve from 0.78947
# Epoch 27/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.4905 - acc: 0.8795 - val_loss: 0.7682 - val_acc: 0.6316
#
# Epoch 00027: val_acc did not improve from 0.78947
# Epoch 28/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.4191 - acc: 0.8980 - val_loss: 0.7023 - val_acc: 0.6842
#
# Epoch 00028: val_acc did not improve from 0.78947
# Epoch 29/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.4562 - acc: 0.8888 - val_loss: 0.6214 - val_acc: 0.7368
#
# Epoch 00029: val_acc did not improve from 0.78947
# Epoch 30/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.4274 - acc: 0.9073 - val_loss: 0.6182 - val_acc: 0.7895
#
# Epoch 00030: val_acc did not improve from 0.78947
# Epoch 31/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.4744 - acc: 0.8610 - val_loss: 0.6322 - val_acc: 0.7895
#
# Epoch 00031: val_acc did not improve from 0.78947
# Epoch 32/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.3936 - acc: 0.8980 - val_loss: 0.5972 - val_acc: 0.7368
#
# Epoch 00032: val_acc did not improve from 0.78947
# Epoch 33/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.4230 - acc: 0.8888 - val_loss: 0.5269 - val_acc: 0.8421
#
# Epoch 00033: val_acc improved from 0.78947 to 0.84211, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial3-improvement-BEST.hdf5
# Epoch 34/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.4215 - acc: 0.8980 - val_loss: 0.5933 - val_acc: 0.7368
#
# Epoch 00034: val_acc did not improve from 0.84211
# Epoch 35/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.3600 - acc: 0.9351 - val_loss: 0.6058 - val_acc: 0.7895
#
# Epoch 00035: val_acc did not improve from 0.84211
# Epoch 36/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.5169 - acc: 0.8620 - val_loss: 0.6161 - val_acc: 0.7895
#
# Epoch 00036: val_acc did not improve from 0.84211
# Epoch 37/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.4180 - acc: 0.8702 - val_loss: 0.5622 - val_acc: 0.7895
#
# Epoch 00037: val_acc did not improve from 0.84211
# Epoch 38/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.3555 - acc: 0.9351 - val_loss: 0.5528 - val_acc: 0.7895
#
# Epoch 00038: val_acc did not improve from 0.84211
# Epoch 39/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.3651 - acc: 0.9073 - val_loss: 0.5700 - val_acc: 0.7895
#
# Epoch 00039: val_acc did not improve from 0.84211
# Epoch 40/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.3329 - acc: 0.9259 - val_loss: 0.5853 - val_acc: 0.7368
#
# Epoch 00040: val_acc did not improve from 0.84211
# Epoch 41/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.3444 - acc: 0.8898 - val_loss: 0.5568 - val_acc: 0.8421
#
# Epoch 00041: val_acc did not improve from 0.84211
# Epoch 42/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.3307 - acc: 0.9073 - val_loss: 0.5757 - val_acc: 0.8421
#
# Epoch 00042: val_acc did not improve from 0.84211
# Epoch 43/200
# 27/27 [==============================] - 6s 228ms/step - loss: 0.4396 - acc: 0.8991 - val_loss: 1.0143 - val_acc: 0.5789
#
# Epoch 00043: val_acc did not improve from 0.84211
# Epoch 44/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.3686 - acc: 0.9259 - val_loss: 0.6309 - val_acc: 0.6842
#
# Epoch 00044: val_acc did not improve from 0.84211
# Epoch 45/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.3186 - acc: 0.9629 - val_loss: 0.6130 - val_acc: 0.7895
#
# Epoch 00045: val_acc did not improve from 0.84211
# Epoch 46/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.3394 - acc: 0.9166 - val_loss: 0.6397 - val_acc: 0.6842
#
# Epoch 00046: val_acc did not improve from 0.84211
# Epoch 47/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.3147 - acc: 0.9351 - val_loss: 0.6788 - val_acc: 0.6842
#
# Epoch 00047: val_acc did not improve from 0.84211
# Epoch 48/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.2947 - acc: 0.9444 - val_loss: 0.6581 - val_acc: 0.7368
#
# Epoch 00048: val_acc did not improve from 0.84211
# Epoch 00048: early stopping
# Trial 4
# Epoch 1/200
# 27/27 [==============================] - 6s 212ms/step - loss: 0.9855 - acc: 0.5005 - val_loss: 1.0644 - val_acc: 0.3158
#
# Epoch 00001: val_acc improved from -inf to 0.31579, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial4-improvement-BEST.hdf5
# Epoch 2/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.9713 - acc: 0.5098 - val_loss: 0.8080 - val_acc: 0.6842
#
# Epoch 00002: val_acc improved from 0.31579 to 0.68421, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial4-improvement-BEST.hdf5
# Epoch 3/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.9463 - acc: 0.5644 - val_loss: 0.8453 - val_acc: 0.7368
#
# Epoch 00003: val_acc improved from 0.68421 to 0.73684, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial4-improvement-BEST.hdf5
# Epoch 4/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.9271 - acc: 0.5088 - val_loss: 0.8221 - val_acc: 0.5789
#
# Epoch 00004: val_acc did not improve from 0.73684
# Epoch 5/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.8998 - acc: 0.5366 - val_loss: 0.7782 - val_acc: 0.6842
#
# Epoch 00005: val_acc did not improve from 0.73684
# Epoch 6/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.9281 - acc: 0.4727 - val_loss: 0.8713 - val_acc: 0.3158
#
# Epoch 00006: val_acc did not improve from 0.73684
# Epoch 7/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.8488 - acc: 0.5366 - val_loss: 0.8955 - val_acc: 0.3158
#
# Epoch 00007: val_acc did not improve from 0.73684
# Epoch 8/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.8797 - acc: 0.5005 - val_loss: 0.8274 - val_acc: 0.3158
#
# Epoch 00008: val_acc did not improve from 0.73684
# Epoch 9/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.8563 - acc: 0.5551 - val_loss: 0.7887 - val_acc: 0.7895
#
# Epoch 00009: val_acc improved from 0.73684 to 0.78947, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial4-improvement-BEST.hdf5
# Epoch 10/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.8200 - acc: 0.5273 - val_loss: 0.8047 - val_acc: 0.3158
#
# Epoch 00010: val_acc did not improve from 0.78947
# Epoch 11/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.8068 - acc: 0.5551 - val_loss: 0.8104 - val_acc: 0.4211
#
# Epoch 00011: val_acc did not improve from 0.78947
# Epoch 12/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.8321 - acc: 0.4264 - val_loss: 0.7446 - val_acc: 0.6842
#
# Epoch 00012: val_acc did not improve from 0.78947
# Epoch 13/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.7682 - acc: 0.5458 - val_loss: 0.7840 - val_acc: 0.3158
#
# Epoch 00013: val_acc did not improve from 0.78947
# Epoch 14/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.7753 - acc: 0.5088 - val_loss: 0.7619 - val_acc: 0.4737
#
# Epoch 00014: val_acc did not improve from 0.78947
# Epoch 15/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.7602 - acc: 0.5366 - val_loss: 0.8208 - val_acc: 0.3158
#
# Epoch 00015: val_acc did not improve from 0.78947
# Epoch 16/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.7605 - acc: 0.5283 - val_loss: 0.7492 - val_acc: 0.5263
#
# Epoch 00016: val_acc did not improve from 0.78947
# Epoch 17/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.7404 - acc: 0.5644 - val_loss: 0.7457 - val_acc: 0.4211
#
# Epoch 00017: val_acc did not improve from 0.78947
# Epoch 18/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.7202 - acc: 0.5829 - val_loss: 0.7777 - val_acc: 0.3158
#
# Epoch 00018: val_acc did not improve from 0.78947
# Epoch 19/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.7204 - acc: 0.6025 - val_loss: 0.7358 - val_acc: 0.5263
#
# Epoch 00019: val_acc did not improve from 0.78947
# Epoch 20/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.6993 - acc: 0.6756 - val_loss: 0.7070 - val_acc: 0.7895
#
# Epoch 00020: val_acc did not improve from 0.78947
# Epoch 21/200
# 27/27 [==============================] - 5s 189ms/step - loss: 0.6840 - acc: 0.6766 - val_loss: 0.6887 - val_acc: 0.7895
#
# Epoch 00021: val_acc did not improve from 0.78947
# Epoch 22/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.6388 - acc: 0.7497 - val_loss: 0.6230 - val_acc: 0.7895
#
# Epoch 00022: val_acc did not improve from 0.78947
# Epoch 23/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.6739 - acc: 0.6756 - val_loss: 0.7024 - val_acc: 0.6842
#
# Epoch 00023: val_acc did not improve from 0.78947
# Epoch 24/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.6128 - acc: 0.7127 - val_loss: 0.7529 - val_acc: 0.5263
#
# Epoch 00024: val_acc did not improve from 0.78947
# Epoch 25/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.6768 - acc: 0.7044 - val_loss: 0.7660 - val_acc: 0.5263
#
# Epoch 00025: val_acc did not improve from 0.78947
# Epoch 26/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.6308 - acc: 0.7219 - val_loss: 0.5995 - val_acc: 0.8421
#
# Epoch 00026: val_acc improved from 0.78947 to 0.84211, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial4-improvement-BEST.hdf5
# Epoch 27/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.5773 - acc: 0.7600 - val_loss: 0.7298 - val_acc: 0.5789
#
# Epoch 00027: val_acc did not improve from 0.84211
# Epoch 28/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.5362 - acc: 0.7776 - val_loss: 0.6445 - val_acc: 0.6316
#
# Epoch 00028: val_acc did not improve from 0.84211
# Epoch 29/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.5595 - acc: 0.8424 - val_loss: 0.7648 - val_acc: 0.5263
#
# Epoch 00029: val_acc did not improve from 0.84211
# Epoch 30/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.5210 - acc: 0.8239 - val_loss: 0.5272 - val_acc: 0.8421
#
# Epoch 00030: val_acc did not improve from 0.84211
# Epoch 31/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.5899 - acc: 0.7878 - val_loss: 0.6800 - val_acc: 0.6842
#
# Epoch 00031: val_acc did not improve from 0.84211
# Epoch 32/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.5297 - acc: 0.8054 - val_loss: 0.5428 - val_acc: 0.8421
#
# Epoch 00032: val_acc did not improve from 0.84211
# Epoch 33/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.4627 - acc: 0.8702 - val_loss: 0.6742 - val_acc: 0.5789
#
# Epoch 00033: val_acc did not improve from 0.84211
# Epoch 34/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.4534 - acc: 0.8795 - val_loss: 0.5047 - val_acc: 0.8421
#
# Epoch 00034: val_acc did not improve from 0.84211
# Epoch 35/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.4710 - acc: 0.8424 - val_loss: 0.5130 - val_acc: 0.8421
#
# Epoch 00035: val_acc did not improve from 0.84211
# Epoch 36/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.5166 - acc: 0.8249 - val_loss: 0.5020 - val_acc: 0.8421
#
# Epoch 00036: val_acc did not improve from 0.84211
# Epoch 37/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.4592 - acc: 0.8888 - val_loss: 0.5413 - val_acc: 0.8421
#
# Epoch 00037: val_acc did not improve from 0.84211
# Epoch 38/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.4495 - acc: 0.8424 - val_loss: 0.5722 - val_acc: 0.8421
#
# Epoch 00038: val_acc did not improve from 0.84211
# Epoch 39/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.4034 - acc: 0.8795 - val_loss: 0.5108 - val_acc: 0.7895
#
# Epoch 00039: val_acc did not improve from 0.84211
# Epoch 40/200
# 27/27 [==============================] - 6s 232ms/step - loss: 0.4144 - acc: 0.8610 - val_loss: 0.5197 - val_acc: 0.8947
#
# Epoch 00040: val_acc improved from 0.84211 to 0.89474, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial4-improvement-BEST.hdf5
# Epoch 41/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.4237 - acc: 0.8713 - val_loss: 0.5374 - val_acc: 0.8947
#
# Epoch 00041: val_acc did not improve from 0.89474
# Epoch 42/200
# 27/27 [==============================] - 8s 308ms/step - loss: 0.3719 - acc: 0.8980 - val_loss: 0.6018 - val_acc: 0.7368
#
# Epoch 00042: val_acc did not improve from 0.89474
# Epoch 43/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.3815 - acc: 0.8980 - val_loss: 0.5586 - val_acc: 0.8421
#
# Epoch 00043: val_acc did not improve from 0.89474
# Epoch 44/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.3992 - acc: 0.8888 - val_loss: 0.6307 - val_acc: 0.7895
#
# Epoch 00044: val_acc did not improve from 0.89474
# Epoch 45/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.3689 - acc: 0.9166 - val_loss: 0.4788 - val_acc: 0.8947
#
# Epoch 00045: val_acc did not improve from 0.89474
# Epoch 46/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.3489 - acc: 0.9073 - val_loss: 0.4944 - val_acc: 0.7895
#
# Epoch 00046: val_acc did not improve from 0.89474
# Epoch 47/200
# 27/27 [==============================] - 5s 171ms/step - loss: 0.3773 - acc: 0.8702 - val_loss: 0.5306 - val_acc: 0.8421
#
# Epoch 00047: val_acc did not improve from 0.89474
# Epoch 48/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.3790 - acc: 0.8980 - val_loss: 0.6627 - val_acc: 0.6842
#
# Epoch 00048: val_acc did not improve from 0.89474
# Epoch 49/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.3588 - acc: 0.8991 - val_loss: 0.5804 - val_acc: 0.7895
#
# Epoch 00049: val_acc did not improve from 0.89474
# Epoch 50/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.3594 - acc: 0.8980 - val_loss: 0.5287 - val_acc: 0.8947
#
# Epoch 00050: val_acc did not improve from 0.89474
# Epoch 51/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.3749 - acc: 0.8888 - val_loss: 0.5077 - val_acc: 0.8947
#
# Epoch 00051: val_acc did not improve from 0.89474
# Epoch 52/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.3026 - acc: 0.9629 - val_loss: 0.5169 - val_acc: 0.8421
#
# Epoch 00052: val_acc did not improve from 0.89474
# Epoch 53/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.3016 - acc: 0.9351 - val_loss: 0.5030 - val_acc: 0.8421
#
# Epoch 00053: val_acc did not improve from 0.89474
# ...
#
# Epoch 00035: val_acc did not improve from 0.89474
# Epoch 36/200
# 27/27 [==============================] - 5s 168ms/step - loss: 0.3957 - acc: 0.9166 - val_loss: 0.5855 - val_acc: 0.7368
#
# Epoch 00036: val_acc did not improve from 0.89474
# Epoch 37/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.4212 - acc: 0.8888 - val_loss: 0.5106 - val_acc: 0.9474
#
# Epoch 00037: val_acc improved from 0.89474 to 0.94737, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial8-improvement-BEST.hdf5
# Epoch 38/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.4349 - acc: 0.8805 - val_loss: 0.5348 - val_acc: 0.9474
#
# Epoch 00038: val_acc did not improve from 0.94737
# Epoch 39/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.3922 - acc: 0.9073 - val_loss: 0.5145 - val_acc: 0.8421
#
# Epoch 00039: val_acc did not improve from 0.94737
# Epoch 40/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.3950 - acc: 0.8795 - val_loss: 0.4712 - val_acc: 0.8947
#
# Epoch 00040: val_acc did not improve from 0.94737
# Epoch 41/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.3542 - acc: 0.9351 - val_loss: 0.6554 - val_acc: 0.6842
#
# Epoch 00041: val_acc did not improve from 0.94737
# Epoch 42/200
# 27/27 [==============================] - 10s 386ms/step - loss: 0.3415 - acc: 0.9259 - val_loss: 0.5061 - val_acc: 0.8947
#
# Epoch 00042: val_acc did not improve from 0.94737
# Epoch 43/200
# 27/27 [==============================] - 5s 184ms/step - loss: 0.3459 - acc: 0.9166 - val_loss: 0.4751 - val_acc: 0.8947
#
# Epoch 00043: val_acc did not improve from 0.94737
# Epoch 44/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.3357 - acc: 0.9073 - val_loss: 0.5048 - val_acc: 0.8947
#
# Epoch 00044: val_acc did not improve from 0.94737
# Epoch 45/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.3442 - acc: 0.9166 - val_loss: 0.5325 - val_acc: 0.8947
#
# Epoch 00045: val_acc did not improve from 0.94737
# Epoch 46/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.2859 - acc: 0.9444 - val_loss: 0.5594 - val_acc: 0.8421
#
# Epoch 00046: val_acc did not improve from 0.94737
# Epoch 47/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.3442 - acc: 0.9166 - val_loss: 0.5032 - val_acc: 0.8947
#
# Epoch 00047: val_acc did not improve from 0.94737
# Epoch 48/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.3258 - acc: 0.9444 - val_loss: 0.6282 - val_acc: 0.6842
#
# Epoch 00048: val_acc did not improve from 0.94737
# Epoch 49/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.3362 - acc: 0.9073 - val_loss: 0.5219 - val_acc: 0.8947
#
# Epoch 00049: val_acc did not improve from 0.94737
# Epoch 50/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.3124 - acc: 0.9269 - val_loss: 0.4932 - val_acc: 0.8947
#
# Epoch 00050: val_acc did not improve from 0.94737
# Epoch 51/200
# 27/27 [==============================] - 5s 171ms/step - loss: 0.3316 - acc: 0.9351 - val_loss: 0.5095 - val_acc: 0.9474
#
# Epoch 00051: val_acc did not improve from 0.94737
# Epoch 52/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.3218 - acc: 0.9351 - val_loss: 0.5229 - val_acc: 0.8421
#
# Epoch 00052: val_acc did not improve from 0.94737
# Epoch 53/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.3229 - acc: 0.9351 - val_loss: 0.5512 - val_acc: 0.8421
#
# Epoch 00053: val_acc did not improve from 0.94737
# Epoch 54/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.2838 - acc: 0.9629 - val_loss: 0.5158 - val_acc: 0.8421
#
# Epoch 00054: val_acc did not improve from 0.94737
# Epoch 55/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.3043 - acc: 0.9444 - val_loss: 0.5279 - val_acc: 0.8421
#
# Epoch 00055: val_acc did not improve from 0.94737
# Epoch 00055: early stopping
# Trial 9
# Epoch 1/200
# 27/27 [==============================] - 6s 239ms/step - loss: 1.0210 - acc: 0.4902 - val_loss: 1.0822 - val_acc: 0.3158
#
# Epoch 00001: val_acc improved from -inf to 0.31579, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial9-improvement-BEST.hdf5
# Epoch 2/200
# 27/27 [==============================] - 4s 163ms/step - loss: 1.0004 - acc: 0.4820 - val_loss: 1.0218 - val_acc: 0.3158
#
# Epoch 00002: val_acc did not improve from 0.31579
# Epoch 3/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.9449 - acc: 0.5190 - val_loss: 0.8998 - val_acc: 0.3158
#
# Epoch 00003: val_acc did not improve from 0.31579
# Epoch 4/200
# 27/27 [==============================] - 4s 155ms/step - loss: 0.8737 - acc: 0.5273 - val_loss: 0.8866 - val_acc: 0.3158
#
# Epoch 00004: val_acc did not improve from 0.31579
# Epoch 5/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.9035 - acc: 0.4449 - val_loss: 1.0196 - val_acc: 0.3158
#
# Epoch 00005: val_acc did not improve from 0.31579
# Epoch 6/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.8694 - acc: 0.5180 - val_loss: 0.8210 - val_acc: 0.5789
#
# Epoch 00006: val_acc improved from 0.31579 to 0.57895, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial9-improvement-BEST.hdf5
# Epoch 7/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.8753 - acc: 0.4727 - val_loss: 0.8357 - val_acc: 0.3684
#
# Epoch 00007: val_acc did not improve from 0.57895
# Epoch 8/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.8699 - acc: 0.4810 - val_loss: 0.8776 - val_acc: 0.3158
#
# Epoch 00008: val_acc did not improve from 0.57895
# Epoch 9/200
# 27/27 [==============================] - 5s 177ms/step - loss: 0.7947 - acc: 0.5644 - val_loss: 1.0333 - val_acc: 0.3158
#
# Epoch 00009: val_acc did not improve from 0.57895
# Epoch 10/200
# 27/27 [==============================] - 5s 173ms/step - loss: 0.8559 - acc: 0.5561 - val_loss: 0.7900 - val_acc: 0.6316
#
# Epoch 00010: val_acc improved from 0.57895 to 0.63158, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial9-improvement-BEST.hdf5
# Epoch 11/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.8103 - acc: 0.4449 - val_loss: 0.7931 - val_acc: 0.4737
#
# Epoch 00011: val_acc did not improve from 0.63158
# Epoch 12/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.7993 - acc: 0.5190 - val_loss: 0.8624 - val_acc: 0.3158
#
# Epoch 00012: val_acc did not improve from 0.63158
# Epoch 13/200
# 27/27 [==============================] - 8s 305ms/step - loss: 0.7792 - acc: 0.6200 - val_loss: 0.7384 - val_acc: 0.6842
#
# Epoch 00013: val_acc improved from 0.63158 to 0.68421, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial9-improvement-BEST.hdf5
# Epoch 14/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.7578 - acc: 0.5376 - val_loss: 0.7919 - val_acc: 0.3158
#
# Epoch 00014: val_acc did not improve from 0.68421
# Epoch 15/200
# 27/27 [==============================] - 5s 169ms/step - loss: 0.7453 - acc: 0.6293 - val_loss: 0.7643 - val_acc: 0.5789
#
# Epoch 00015: val_acc did not improve from 0.68421
# Epoch 16/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.7428 - acc: 0.5839 - val_loss: 0.7178 - val_acc: 0.6842
#
# Epoch 00016: val_acc did not improve from 0.68421
# Epoch 17/200
# 27/27 [==============================] - 4s 166ms/step - loss: 0.6708 - acc: 0.7312 - val_loss: 0.9492 - val_acc: 0.3158
#
# Epoch 00017: val_acc did not improve from 0.68421
# Epoch 18/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.7894 - acc: 0.5469 - val_loss: 0.7250 - val_acc: 0.7368
#
# Epoch 00018: val_acc improved from 0.68421 to 0.73684, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial9-improvement-BEST.hdf5
# Epoch 19/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.7223 - acc: 0.6200 - val_loss: 0.7101 - val_acc: 0.7368
#
# Epoch 00019: val_acc did not improve from 0.73684
# Epoch 20/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.7127 - acc: 0.6571 - val_loss: 0.6765 - val_acc: 0.7368
#
# Epoch 00020: val_acc did not improve from 0.73684
# Epoch 21/200
# 27/27 [==============================] - 5s 167ms/step - loss: 0.6937 - acc: 0.6859 - val_loss: 0.6891 - val_acc: 0.7895
#
# Epoch 00021: val_acc improved from 0.73684 to 0.78947, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial9-improvement-BEST.hdf5
# Epoch 22/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.6985 - acc: 0.6488 - val_loss: 0.6797 - val_acc: 0.7368
#
# Epoch 00022: val_acc did not improve from 0.78947
# Epoch 23/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.6447 - acc: 0.7508 - val_loss: 0.8486 - val_acc: 0.3684
#
# Epoch 00023: val_acc did not improve from 0.78947
# Epoch 24/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.7166 - acc: 0.6395 - val_loss: 0.8412 - val_acc: 0.3684
#
# Epoch 00024: val_acc did not improve from 0.78947
# Epoch 25/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.6845 - acc: 0.6663 - val_loss: 0.6667 - val_acc: 0.7368
#
# Epoch 00025: val_acc did not improve from 0.78947
# Epoch 26/200
# 27/27 [==============================] - 4s 157ms/step - loss: 0.5888 - acc: 0.8054 - val_loss: 0.5891 - val_acc: 0.8421
#
# Epoch 00026: val_acc improved from 0.78947 to 0.84211, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial9-improvement-BEST.hdf5
# Epoch 27/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.6300 - acc: 0.7230 - val_loss: 0.8176 - val_acc: 0.4737
#
# Epoch 00027: val_acc did not improve from 0.84211
# Epoch 28/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.5442 - acc: 0.7878 - val_loss: 0.6615 - val_acc: 0.6842
#
# Epoch 00028: val_acc did not improve from 0.84211
# Epoch 29/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.5566 - acc: 0.7683 - val_loss: 0.6729 - val_acc: 0.6316
#
# Epoch 00029: val_acc did not improve from 0.84211
# Epoch 30/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.4935 - acc: 0.8332 - val_loss: 0.6153 - val_acc: 0.7368
#
# Epoch 00030: val_acc did not improve from 0.84211
# Epoch 31/200
# 27/27 [==============================] - 4s 163ms/step - loss: 0.5382 - acc: 0.7590 - val_loss: 0.6538 - val_acc: 0.6316
#
# Epoch 00031: val_acc did not improve from 0.84211
# Epoch 32/200
# 27/27 [==============================] - 4s 160ms/step - loss: 0.5364 - acc: 0.8054 - val_loss: 0.5298 - val_acc: 0.8947
#
# Epoch 00032: val_acc improved from 0.84211 to 0.89474, saving model to /analysis/fabiane/models/MS/pretrained/rebuild_64Net/new_script/remove_lesions/weights-augm-trial9-improvement-BEST.hdf5
# Epoch 33/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.5101 - acc: 0.8332 - val_loss: 0.5882 - val_acc: 0.6842
#
# Epoch 00033: val_acc did not improve from 0.89474
# Epoch 34/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.5226 - acc: 0.8146 - val_loss: 0.5688 - val_acc: 0.6316
#
# Epoch 00034: val_acc did not improve from 0.89474
# Epoch 35/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.4587 - acc: 0.8424 - val_loss: 0.5322 - val_acc: 0.8421
#
# Epoch 00035: val_acc did not improve from 0.89474
# Epoch 36/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.3890 - acc: 0.9351 - val_loss: 0.5137 - val_acc: 0.8421
#
# Epoch 00036: val_acc did not improve from 0.89474
# Epoch 37/200
# 27/27 [==============================] - 4s 155ms/step - loss: 0.4172 - acc: 0.8795 - val_loss: 0.5283 - val_acc: 0.8421
#
# Epoch 00037: val_acc did not improve from 0.89474
# Epoch 38/200
# 27/27 [==============================] - 5s 171ms/step - loss: 0.4890 - acc: 0.8424 - val_loss: 0.6132 - val_acc: 0.6842
#
# Epoch 00038: val_acc did not improve from 0.89474
# Epoch 39/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.3826 - acc: 0.9259 - val_loss: 0.5464 - val_acc: 0.7368
#
# Epoch 00039: val_acc did not improve from 0.89474
# Epoch 40/200
# 27/27 [==============================] - 4s 159ms/step - loss: 0.4421 - acc: 0.8713 - val_loss: 0.5295 - val_acc: 0.8421
#
# Epoch 00040: val_acc did not improve from 0.89474
# Epoch 41/200
# 27/27 [==============================] - 7s 244ms/step - loss: 0.4547 - acc: 0.8795 - val_loss: 0.5374 - val_acc: 0.8421
#
# Epoch 00041: val_acc did not improve from 0.89474
# Epoch 42/200
# 27/27 [==============================] - 4s 156ms/step - loss: 0.3620 - acc: 0.9259 - val_loss: 0.5149 - val_acc: 0.8947
#
# Epoch 00042: val_acc did not improve from 0.89474
# Epoch 43/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.4012 - acc: 0.8805 - val_loss: 0.5390 - val_acc: 0.8947
#
# Epoch 00043: val_acc did not improve from 0.89474
# Epoch 44/200
# 27/27 [==============================] - 4s 161ms/step - loss: 0.4133 - acc: 0.8795 - val_loss: 0.5371 - val_acc: 0.8421
#
# Epoch 00044: val_acc did not improve from 0.89474
# Epoch 45/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.4099 - acc: 0.8620 - val_loss: 0.5799 - val_acc: 0.8421
#
# Epoch 00045: val_acc did not improve from 0.89474
# Epoch 46/200
# 27/27 [==============================] - 4s 158ms/step - loss: 0.4005 - acc: 0.8980 - val_loss: 0.5752 - val_acc: 0.8421
#
# Epoch 00046: val_acc did not improve from 0.89474
# Epoch 47/200
# 27/27 [==============================] - 4s 165ms/step - loss: 0.4169 - acc: 0.9259 - val_loss: 0.6405 - val_acc: 0.6842
#
# Epoch 00047: val_acc did not improve from 0.89474
# Epoch 48/200
# 27/27 [==============================] - 4s 164ms/step - loss: 0.4088 - acc: 0.9176 - val_loss: 0.5688 - val_acc: 0.7895
#
# Epoch 00048: val_acc did not improve from 0.89474
# Epoch 49/200
# 27/27 [==============================] - 4s 162ms/step - loss: 0.3597 - acc: 0.9073 - val_loss: 0.6740 - val_acc: 0.7368
#
# Epoch 00049: val_acc did not improve from 0.89474
# Epoch 50/200
# 27/27 [==============================] - 5s 171ms/step - loss: 0.3245 - acc: 0.9166 - val_loss: 0.5556 - val_acc: 0.7895
#
# Epoch 00050: val_acc did not improve from 0.89474
# Epoch 51/200
# 27/27 [==============================] - 4s 155ms/step - loss: 0.4018 - acc: 0.8888 - val_loss: 0.5641 - val_acc: 0.7895
#
# Epoch 00051: val_acc did not improve from 0.89474
# Epoch 00051: early stopping
# Training Time: 0.0h:40.0m:12.518653154373169s
# Validation final accuracies:
#  [0.8421052631578947, 0.8947368421052632, 0.7368421052631579, 0.7368421052631579, 0.7368421052631579, 0.7894736842105263, 0.7894736842105263, 0.7368421052631579, 0.8421052631578947, 0.7894736842105263]
# Validation final accuracies mean: 0.7894736842105263
# Validation best accuracies:
#  [0.8947368421052632, 0.8947368421052632, 0.9473684210526315, 0.8421052631578947, 0.8947368421052632, 0.8947368421052632, 0.8947368421052632, 0.8421052631578947, 0.9473684210526315, 0.8947368421052632]
# Validation best accuracies mean: 0.8947368421052632
# Validation balanced accuracies:
#  [0.7948717948717949, 0.8333333333333333, 0.717948717948718, 0.6730769230769231, 0.7628205128205128, 0.8012820512820513, 0.8012820512820513, 0.717948717948718, 0.7948717948717949, 0.7115384615384616]
# Validation balanced accuracies mean: 0.7608974358974359
# Validation final sensitivities:
#  [0.6666666666666666, 0.6666666666666666, 0.6666666666666666, 0.5, 0.8333333333333334, 0.8333333333333334, 0.8333333333333334, 0.6666666666666666, 0.6666666666666666, 0.5]
# Validation final sensitivities' mean: 0.6833333333333333
# Validation final specificities:
#  [0.9230769230769231, 1.0, 0.7692307692307693, 0.8461538461538461, 0.6923076923076923, 0.7692307692307693, 0.7692307692307693, 0.7692307692307693, 0.9230769230769231, 0.9230769230769231]
# Validation final specificities' mean: 0.8384615384615385

# %% [markdown]
# val bal 81%

# %%
training_time = time.time() - start_time

# %% [markdown]
# # Evaluation

# %%
weights = ["weights-augm-trial%i-improvement-BEST.hdf5"%i for i in range(num_trials)]

# %%
# load holdout set
test_loader = CISDataset(X_holdout, y_holdout, transform=[intensity], batch_size=1, shuffle=False)

# %%
accuracies = []
balanced_accuracies = []
sensitivities = []
specificities = []
auc_scores = []
tprs = []
mean_fpr = np.linspace(0, 1, 100)

plt.figure(figsize=(10, 8))

for fold, weight in enumerate(weights):
    print("Fold {}".format(fold))
    model = load_model(model_path)
    model_dir = os.path.join(result_dir, weight)
    model.load_weights(model_dir)
    
    opti = Adam(lr=lr, decay=lr_decay)
    model.compile(optimizer=opti,
              loss='binary_crossentropy',
              metrics=['accuracy'])
    
    # Evaluate
    res = model.evaluate_generator(test_loader)
    y_pred = model.predict_generator(test_loader)
    bal_acc = balanced_accuracy(y_holdout, y_pred>0.5)
    sens = sensitivity(y_holdout, y_pred>0.5)
    spec = specificity(y_holdout, y_pred>0.5)
    roc_auc = roc_auc_score(y_holdout, y_pred)
    fpr, tpr, thresholds = roc_curve(y_holdout, y_pred)   
    # Store results
    accuracies.append(res[1])
    balanced_accuracies.append(bal_acc)
    sensitivities.append(sens)
    specificities.append(spec)
    auc_scores.append(roc_auc)
    tprs.append(interp(mean_fpr, fpr, tpr))
    tprs[-1][0] = 0.0
    # Print results
    print("Model accuracy {:.2f} %".format(res[1]*100))
    print("Balanced accuracy {:.2f} %".format(bal_acc*100))
    print("Sensitivity {:.2f} %".format(sens*100))
    print("Specificity {:.2f} %".format(spec*100))
    print("Area Under the Receiver Operating Curve (ROC AUC score) {:.2f}".format(roc_auc*100))
    plt.plot(fpr, tpr, lw=1, alpha=0.3,
             label='ROC trial %d (AUC = %0.2f)' % (fold, roc_auc))
    
print("######## Final results ########")
print("Accuracy mean {:.2f} %".format(np.mean(accuracies)*100))
print("Balanced accuracy mean {:.2f} %".format(np.mean(balanced_accuracies)*100))
print("Sensitivity mean {:.2f} %".format(np.mean(sensitivities)*100))
print("Specificity mean {:.2f} %".format(np.mean(specificities)*100))
print("Mean ROC AUC score {:.2f}".format(np.mean(auc_scores)*100))

# Plot ROC Curves
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
         label='Chance', alpha=.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
#assert(mean_auc == np.mean(auc_scores))
std_auc = np.std(auc_scores)
plt.plot(mean_fpr, mean_tpr, color='b',
         label=r'Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (np.mean(auc_scores), std_auc),
         lw=2, alpha=.8)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
plt.fill_between(mean_fpr, tprs_lower, tprs_upper, color='grey', alpha=.2,
                 label=r'$\pm$ 1 std. dev.')

plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
# Out:
# Fold 0
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()
# Model accuracy 73.91 %
# Balanced accuracy 71.15 %
# Sensitivity 92.31 %
# Specificity 50.00 %
# Area Under the Receiver Operating Curve (ROC AUC score) 93.08
# Fold 1
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()
# Model accuracy 82.61 %
# Balanced accuracy 82.31 %
# Sensitivity 84.62 %
# Specificity 80.00 %
# Area Under the Receiver Operating Curve (ROC AUC score) 91.54
# Fold 2
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()
# Model accuracy 82.61 %
# Balanced accuracy 81.15 %
# Sensitivity 92.31 %
# Specificity 70.00 %
# Area Under the Receiver Operating Curve (ROC AUC score) 90.77
# Fold 3
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()
# Model accuracy 86.96 %
# Balanced accuracy 87.31 %
# Sensitivity 84.62 %
# Specificity 90.00 %
# Area Under the Receiver Operating Curve (ROC AUC score) 94.62
# Fold 4
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()
# Model accuracy 78.26 %
# Balanced accuracy 76.15 %
# Sensitivity 92.31 %
# Specificity 60.00 %
# Area Under the Receiver Operating Curve (ROC AUC score) 93.85
# Fold 5
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()
# Model accuracy 78.26 %
# Balanced accuracy 77.31 %
# Sensitivity 84.62 %
# Specificity 70.00 %
# Area Under the Receiver Operating Curve (ROC AUC score) 90.77
# Fold 6
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()
# Model accuracy 78.26 %
# Balanced accuracy 76.15 %
# Sensitivity 92.31 %
# Specificity 60.00 %
# Area Under the Receiver Operating Curve (ROC AUC score) 90.77
# Fold 7
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()
# Model accuracy 73.91 %
# Balanced accuracy 72.31 %
# Sensitivity 84.62 %
# Specificity 60.00 %
# Area Under the Receiver Operating Curve (ROC AUC score) 90.00
# Fold 8
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()
# Model accuracy 82.61 %
# Balanced accuracy 81.15 %
# Sensitivity 92.31 %
# Specificity 70.00 %
# Area Under the Receiver Operating Curve (ROC AUC score) 93.08
# Fold 9
# /home/fabiane/anaconda2/envs/postal/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   app.launch_new_instance()
# Model accuracy 78.26 %
# Balanced accuracy 77.31 %
# Sensitivity 84.62 %
# Specificity 70.00 %
# Area Under the Receiver Operating Curve (ROC AUC score) 90.00
# ######## Final results ########
# Accuracy mean 79.57 %
# Balanced accuracy mean 78.23 %
# Sensitivity mean 88.46 %
# Specificity mean 68.00 %
# Mean ROC AUC score 91.85

# %%
total_time = time.time() - start_time

# %%
print("Training Time: {}h:{}m:{}s".format(
            training_time//3600, (training_time//60)%60, training_time%60))
print("Total time elapsed: {}h:{}m:{}s".format(
            total_time//3600, (total_time//60)%60, total_time%60))
# Out:
# Training Time: 0.0h:40.0m:12.539326906204224s
# Total time elapsed: 0.0h:42.0m:15.997339725494385s

# %%
quit()
